# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Prepare Movie Data

# %%
# import dataset from movie_lens and omdb
#movie_lens data contains the columns movieId, genre, movie_nm, released
#omdb data contains title, actors, directors, year

movies_ml = pd.read_csv('data/movies_clean.csv')
movies_omdb = pd.read_csv('data/all_movies_info.csv')

# %%
movies_ml.head()
# Out:
#    movieId                                       genres  \
# 0        1  Adventure|Animation|Children|Comedy|Fantasy
# 1        2                   Adventure|Children|Fantasy
# 2        3                               Comedy|Romance
# 3        4                         Comedy|Drama|Romance
# 4        5                                       Comedy
#
#                        movie_nm  released
# 0                    Toy Story       1995
# 1                      Jumanji       1995
# 2             Grumpier Old Men       1995
# 3            Waiting to Exhale       1995
# 4  Father of the Bride Part II       1995

# %%
movies_omdb.head()
# Out:
#                  Title                                             Actors  \
# 0           Home Alone  Macaulay Culkin, Joe Pesci, Daniel Stern, John...
# 1                Ghost  Patrick Swayze, Demi Moore, Tony Goldwyn, Stan...
# 2   Dances with Wolves  Kevin Costner, Mary McDonnell, Graham Greene, ...
# 3         Pretty Woman  Richard Gere, Julia Roberts, Ralph Bellamy, Ja...
# 4  I, the Worst of All  Assumpta Serna, Dominique Sanda, Héctor Alteri...
#
#               Director  Year
# 0       Chris Columbus  1990
# 1         Jerry Zucker  1990
# 2        Kevin Costner  1990
# 3       Garry Marshall  1990
# 4  María Luisa Bemberg  1990

# %%
# prepare both datasets to be joined on the Title column

# rename movie_nm to Title in movies_ml dataframe

movies_ml = movies_ml.rename(columns = {'movie_nm': 'Title'})

# apply strip method on the title columns of both datasets 

movies_ml['Title'] = movies_ml['Title'].str.strip()
movies_omdb['Title'] = movies_omdb['Title'].str.strip()

# %%
# complete join of dataframes

movies = pd.merge(movies_ml, movies_omdb, how = 'inner',on = 'Title' )

movies.shape
# Out:
# (31779, 7)

# %%
# apply strip method on the title columns of both datasets 

movies_ml['Title'] = movies_ml['Title'].str.strip()
movies_omdb['Title'] = movies_omdb['Title'].str.strip()

# %%
all_movies = movies.copy()

# %%
all_movies = all_movies[['movieId', 'Title', 'genres', 'released', 'Actors', 'Director']]

all_movies.head()
# Out:
#    movieId                        Title  \
# 0        1                    Toy Story
# 1        2                      Jumanji
# 2        3             Grumpier Old Men
# 3        4            Waiting to Exhale
# 4        5  Father of the Bride Part II
#
#                                         genres  released  \
# 0  Adventure|Animation|Children|Comedy|Fantasy      1995
# 1                   Adventure|Children|Fantasy      1995
# 2                               Comedy|Romance      1995
# 3                         Comedy|Drama|Romance      1995
# 4                                       Comedy      1995
#
#                                               Actors         Director
# 0      Tom Hanks, Tim Allen, Don Rickles, Jim Varney    John Lasseter
# 1  Robin Williams, Jonathan Hyde, Kirsten Dunst, ...     Joe Johnston
# 2  Walter Matthau, Jack Lemmon, Sophia Loren, Ann...    Howard Deutch
# 3  Whitney Houston, Angela Bassett, Loretta Devin...  Forest Whitaker
# 4  Steve Martin, Diane Keaton, Martin Short, Kimb...    Charles Shyer

# %% [markdown]
# #### Prepare Ratings Data

# %%
ratings = pd.read_csv('data/ratings.csv')

# %%
print(ratings.shape)
ratings.head()
# Out:
# (26024289, 4)
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %% [markdown]
# #### Reduce the size of ratings dataframe
#
# To reduce the size of the ratings dataframe we needed to decide on a meaningful way to shrink the data. We conducted exploratory analysis and decided to split the data based on users who rated within a range of the mean number of ratings per user.

# %%
# count number of ratings per user
user_ratings_grp = pd.DataFrame(ratings.groupby('userId')['rating'].count())

# %%
user_ratings_grp.head()
# Out:
#         rating
# userId
# 1           27
# 2           22
# 3           10
# 4           62
# 5           26

# %%
# find mean of number of ratings per user
avg_nratings = user_ratings_grp['rating'].mean()

avg_nratings
# Out:
# 96.06745393065974

# %%
# find users who rated within +10 or - 10 of the mean

avg_activity = user_ratings_grp[(user_ratings_grp['rating'] >= 85) & (user_ratings_grp['rating'] <= 105)]
print(avg_activity.shape)

# rename column

avg_activity = avg_activity.rename(columns = {'rating': 'rating_ct'})

avg_activity.head()
# Out:
# (11910, 1)
#         rating_ct
# userId
# 60            105
# 76            105
# 89            100
# 107            87
# 115           105

# %%
# combine avg_activity and ratings to only return the ratings for the people that are 
#in the avg_activity dataframe

new_ratings = pd.merge(avg_activity, ratings, how = 'inner', on = 'userId')

print(new_ratings.shape)
new_ratings.head()
# Out:
# (1133047, 5)
#    userId  rating_ct  movieId  rating   timestamp
# 0      60        105      112     2.5  1136304271
# 1      60        105      153     2.5  1136306947
# 2      60        105      163     4.0  1136304313
# 3      60        105      165     4.0  1136306968
# 4      60        105      168     0.5  1136304366

# %% [markdown]
# Combine Ratings and Movies Dataset

# %%
mrd = pd.merge(new_ratings, all_movies,how = 'inner', on = 'movieId')

# %%
print(mrd.shape)
mrd.head()
# Out:
# (774593, 10)
#    userId  rating_ct  movieId  rating   timestamp                Title  \
# 0      60        105      112     2.5  1136304271  Rumble in the Bronx
# 1     123         99      112     3.0   968570443  Rumble in the Bronx
# 2     131         87      112     2.0   852309667  Rumble in the Bronx
# 3     595         91      112     5.0   839936904  Rumble in the Bronx
# 4     627         85      112     3.0  1136306189  Rumble in the Bronx
#
#                           genres  released  \
# 0  Action|Adventure|Comedy|Crime      1995
# 1  Action|Adventure|Comedy|Crime      1995
# 2  Action|Adventure|Comedy|Crime      1995
# 3  Action|Adventure|Comedy|Crime      1995
# 4  Action|Adventure|Comedy|Crime      1995
#
#                                              Actors      Director
# 0  Jackie Chan, Anita Mui, Françoise Yip, Bill Tung  Stanley Tong
# 1  Jackie Chan, Anita Mui, Françoise Yip, Bill Tung  Stanley Tong
# 2  Jackie Chan, Anita Mui, Françoise Yip, Bill Tung  Stanley Tong
# 3  Jackie Chan, Anita Mui, Françoise Yip, Bill Tung  Stanley Tong
# 4  Jackie Chan, Anita Mui, Françoise Yip, Bill Tung  Stanley Tong

# %%
# check for nulls

mrd.isnull().sum()
# Out:
# userId       0
# rating_ct    0
# movieId      0
# rating       0
# timestamp    0
# Title        0
# genres       0
# released     0
# Actors       0
# Director     0
# dtype: int64

# %%
mrd.groupby('Title')['rating'].mean().head()
# Out:
# Title
# $5 a Day                            4.000000
# $9.99                               3.833333
# '71                                 3.500000
# 'Hellboy': The Seeds of Creation    3.700000
# 'Til There Was You                  3.410714
# Name: rating, dtype: float64

# %%
mrd.groupby('Title')['rating'].mean().sort_values(ascending=False).head()
# Out:
# Title
# Sister                5.0
# Brown's Requiem       5.0
# The Wizard of Lies    5.0
# Gifted                5.0
# Bush's Brain          5.0
# Name: rating, dtype: float64

# %%
mrd.groupby('Title')['rating'].count().sort_values(ascending=False).head()
# Out:
# Title
# Beauty and the Beast          10872
# Terminator 2: Judgment Day     9490
# Ghost                          9260
# Speed                          6556
# Forrest Gump                   6526
# Name: rating, dtype: int64

# %%
ratingsMeanCount = pd.DataFrame(mrd.groupby('Title')['rating'].mean())
ratingsMeanCount.head()
# Out:
#                                     rating
# Title
# $5 a Day                          4.000000
# $9.99                             3.833333
# '71                               3.500000
# 'Hellboy': The Seeds of Creation  3.700000
# 'Til There Was You                3.410714

# %%
ratingsMeanCount['ratingsCounts'] = pd.DataFrame(mrd.groupby('Title')['rating'].count())
ratingsMeanCount.head()
# Out:
#                                     rating  ratingsCounts
# Title
# $5 a Day                          4.000000              1
# $9.99                             3.833333              3
# '71                               3.500000              3
# 'Hellboy': The Seeds of Creation  3.700000              5
# 'Til There Was You                3.410714             28

# %%
user_movie_rating = mrd.pivot_table(index='userId', columns='Title', values='rating')

# %%
user_movie_rating.head()
# Out:
# Title   $5 a Day  $9.99  '71  'Hellboy': The Seeds of Creation  \
# userId
# 60           NaN    NaN  NaN                               NaN
# 76           NaN    NaN  NaN                               NaN
# 89           NaN    NaN  NaN                               NaN
# 107          NaN    NaN  NaN                               NaN
# 115          NaN    NaN  NaN                               NaN
#
# Title   'Til There Was You  10 Cloverfield Lane  10 Items or Less  \
# userId
# 60                     NaN                  NaN               NaN
# 76                     NaN                  NaN               NaN
# 89                     NaN                  NaN               NaN
# 107                    NaN                  NaN               NaN
# 115                    NaN                  NaN               NaN
#
# Title   10 Questions for the Dalai Lama  10 Things I Hate About You  10 Years  \
# userId
# 60                                  NaN                         NaN       NaN
# 76                                  NaN                         NaN       NaN
# 89                                  NaN                         NaN       NaN
# 107                                 NaN                         NaN       NaN
# 115                                 NaN                         NaN       NaN
#
# Title            ...             Zoom  Zootopia  Zus & Zo  Zuzu Angel  \
# userId           ...
# 60               ...              NaN       NaN       NaN         NaN
# 76               ...              NaN       NaN       NaN         NaN
# 89               ...              NaN       NaN       NaN         NaN
# 107              ...              NaN       NaN       NaN         NaN
# 115              ...              NaN       NaN       NaN         NaN
#
# Title   [REC] 4: Apocalypse  eXistenZ  loudQUIETloud: A Film About the Pixies  \
# userId
# 60                      NaN       NaN                                     NaN
# 76                      NaN       NaN                                     NaN
# 89                      NaN       NaN                                     NaN
# 107                     NaN       NaN                                     NaN
# 115                     NaN       NaN                                     NaN
#
# Title   xXx  xXx: Return of Xander Cage  xXx: State of the Union
# userId
# 60      NaN                         NaN                      NaN
# 76      NaN                         NaN                      NaN
# 89      NaN                         NaN                      NaN
# 107     NaN                         NaN                      NaN
# 115     NaN                         NaN                      NaN
#
# [5 rows x 6860 columns]

# %% [markdown]
# ### Content Recommendation System

# %%
movies_only = mrd[['Title','genres','Director','Actors']]

# %%
movies_only.shape
# Out:
# (774593, 4)

# %%
movies_only.drop_duplicates(keep = 'first',inplace = True)
# Out:
# C:\Users\zkxav\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
movies_only.shape
# Out:
# (7003, 4)

# %%
movies_only.head()
# Out:
#                            Title                         genres  \
# 0            Rumble in the Bronx  Action|Adventure|Comedy|Crime
# 831               Batman Forever  Action|Adventure|Comedy|Crime
# 3098                   Desperado         Action|Romance|Western
# 4099  Die Hard: With a Vengeance          Action|Crime|Thriller
# 8967                First Knight           Action|Drama|Romance
#
#               Director                                             Actors
# 0         Stanley Tong   Jackie Chan, Anita Mui, Françoise Yip, Bill Tung
# 831    Joel Schumacher  Val Kilmer, Tommy Lee Jones, Jim Carrey, Nicol...
# 3098  Robert Rodriguez  Antonio Banderas, Salma Hayek, Joaquim de Alme...
# 4099    John McTiernan  Bruce Willis, Jeremy Irons, Samuel L. Jackson,...
# 8967      Jerry Zucker  Sean Connery, Richard Gere, Julia Ormond, Ben ...

# %%
# remove spaces from actors and director names

def clean_data(x):
    if isinstance(x, list):
        return[str.lower(i.replace(" ", "")) for i in x]
    else:
        if isinstance(x, str):
            return str.lower(x.replace(" ", ""))
        else:
            return ''

# %%
movies_df = movies_only.copy()

# %%
credits = ['Actors', 'Director']

# %%
for credit in credits:
    movies_df[credit] = movies_df[credit].apply(clean_data)

# %%
movies_df.head()
# Out:
#                            Title                         genres  \
# 0            Rumble in the Bronx  Action|Adventure|Comedy|Crime
# 831               Batman Forever  Action|Adventure|Comedy|Crime
# 3098                   Desperado         Action|Romance|Western
# 4099  Die Hard: With a Vengeance          Action|Crime|Thriller
# 8967                First Knight           Action|Drama|Romance
#
#              Director                                             Actors
# 0         stanleytong          jackiechan,anitamui,françoiseyip,billtung
# 831    joelschumacher     valkilmer,tommyleejones,jimcarrey,nicolekidman
# 3098  robertrodriguez  antoniobanderas,salmahayek,joaquimdealmeida,ch...
# 4099    johnmctiernan  brucewillis,jeremyirons,samuell.jackson,graham...
# 8967      jerryzucker       seanconnery,richardgere,juliaormond,bencross

# %%
# remove | from genres

movies_df['genres'] = movies_df['genres'].str.replace("|", " ")

# %%
movies_df.head()
# Out:
#                            Title                         genres  \
# 0            Rumble in the Bronx  Action Adventure Comedy Crime
# 831               Batman Forever  Action Adventure Comedy Crime
# 3098                   Desperado         Action Romance Western
# 4099  Die Hard: With a Vengeance          Action Crime Thriller
# 8967                First Knight           Action Drama Romance
#
#              Director                                             Actors
# 0         stanleytong          jackiechan,anitamui,françoiseyip,billtung
# 831    joelschumacher     valkilmer,tommyleejones,jimcarrey,nicolekidman
# 3098  robertrodriguez  antoniobanderas,salmahayek,joaquimdealmeida,ch...
# 4099    johnmctiernan  brucewillis,jeremyirons,samuell.jackson,graham...
# 8967      jerryzucker       seanconnery,richardgere,juliaormond,bencross

# %%
#combine all data 

def create_soup(x):
    return  x['Actors'].replace(',',' ') + ' ' + x['Director'] + ' ' + ' '.join(x['genres'])

# %%
movies_df['bag_of_words'] = movies_df.apply(create_soup, axis=1)

# %%
movies_df.set_index('Title')
# Out:
#                                                             genres  \
# Title
# Rumble in the Bronx                  Action Adventure Comedy Crime
# Batman Forever                       Action Adventure Comedy Crime
# Desperado                                   Action Romance Western
# Die Hard: With a Vengeance                   Action Crime Thriller
# First Knight                                  Action Drama Romance
# Mallrats                                            Comedy Romance
# Clerks                                                      Comedy
# Hot Shots! Part Deux                             Action Comedy War
# Dead Man                                     Drama Mystery Western
# Die Hard 2                               Action Adventure Thriller
# Batman Returns                                        Action Crime
# Donnie Brasco                                          Crime Drama
# Liar Liar                                                   Comedy
# Grosse Pointe Blank                           Comedy Crime Romance
# Face/Off                               Action Crime Drama Thriller
# City of Angels                               Drama Fantasy Romance
# Cube                                Horror Mystery Sci-Fi Thriller
# Happiness                                             Comedy Drama
# American History X                                     Crime Drama
# Enemy of the State                                 Action Thriller
# Office Space                                          Comedy Crime
# Wing Commander                                       Action Sci-Fi
# Ravenous                                           Horror Thriller
# American Pie                                        Comedy Romance
# Boiler Room                                   Crime Drama Thriller
# Ghost Dog: The Way of the Samurai                      Crime Drama
# Requiem for a Dream                                          Drama
# Charlie's Angels                                     Action Comedy
# Dungeons & Dragons                 Action Adventure Comedy Fantasy
# Valentine                                           Horror Mystery
# ...                                                            ...
# Dadetown                                                     Drama
# Wheel of Time                                          Documentary
# Romanzo Criminale                                      Crime Drama
# Far                                                          Drama
# Heart of America                                             Drama
# Special                                              Drama Fantasy
# Blackwoods                                          Drama Thriller
# Gunless                                Action Comedy Drama Western
# Route Irish                                         Drama Thriller
# Reykjavik-Rotterdam                                 Drama Thriller
# Hammer of the Gods                                          Action
# Child of God                                  Crime Drama Thriller
# Last Will                                           Drama Thriller
# Kill Your Friends                            Comedy Crime Thriller
# Now You See It...                                   Comedy Mystery
# War on Everyone                                             Comedy
# Eating Out 2: Sloppy Seconds                        Comedy Romance
# Spin                                          Comedy Drama Romance
# Craigslist Joe                               Adventure Documentary
# Living on One Dollar                   Adventure Documentary Drama
# Video Games: The Movie                                 Documentary
# Big Star: Nothing Can Hurt Me                          Documentary
# Rams                                            (no genres listed)
# Maggie's Plan                                               Comedy
# Breadcrumb Trail                                       Documentary
# Last Train Home                                  Documentary Drama
# The Wolfpack                                           Documentary
# Such Good People                                    Comedy Mystery
# 4 Moons                                                      Drama
# Seashore                                                     Drama
#
#                                                                             Director  \
# Title
# Rumble in the Bronx                                                      stanleytong
# Batman Forever                                                        joelschumacher
# Desperado                                                            robertrodriguez
# Die Hard: With a Vengeance                                             johnmctiernan
# First Knight                                                             jerryzucker
# Mallrats                                                                  kevinsmith
# Clerks                                                                    kevinsmith
# Hot Shots! Part Deux                                                     jimabrahams
# Dead Man                                                                 jimjarmusch
# Die Hard 2                                                               rennyharlin
# Batman Returns                                                             timburton
# Donnie Brasco                                                             mikenewell
# Liar Liar                                                                 tomshadyac
# Grosse Pointe Blank                                                   georgearmitage
# Face/Off                                                                     johnwoo
# City of Angels                                                        bradsilberling
# Cube                                                                  vincenzonatali
# Happiness                                                                toddsolondz
# American History X                                                          tonykaye
# Enemy of the State                                                         tonyscott
# Office Space                                                               mikejudge
# Wing Commander                                                          chrisroberts
# Ravenous                                                                 antoniabird
# American Pie                                                    paulweitz,chrisweitz
# Boiler Room                                                               benyounger
# Ghost Dog: The Way of the Samurai                                        jimjarmusch
# Requiem for a Dream                                                  darrenaronofsky
# Charlie's Angels                                                                 mcg
# Dungeons & Dragons                                                   courtneysolomon
# Valentine                                                                jamieblanks
# ...                                                                              ...
# Dadetown                                                                  russhexter
# Wheel of Time                                                           wernerherzog
# Romanzo Criminale                                                     micheleplacido
# Far                                                                     andrétéchiné
# Heart of America                                                             uweboll
# Special                                                   halhaberman,jeremypassmore
# Blackwoods                                                                   uweboll
# Gunless                                                              williamphillips
# Route Irish                                                                 kenloach
# Reykjavik-Rotterdam                                                    óskarjónasson
# Hammer of the Gods                                                   farrenblackburn
# Child of God                                                             jamesfranco
# Last Will                                                                  brenthuff
# Kill Your Friends                                                         owenharris
# Now You See It...                                                      duwaynedunham
# War on Everyone                                                  johnmichaelmcdonagh
# Eating Out 2: Sloppy Seconds                                        phillipj.bartell
# Spin                                                                     jaminwinans
# Craigslist Joe                                                          josephgarner
# Living on One Dollar               zachingrasci(co-director),seanleonard(co-direc...
# Video Games: The Movie                                                   jeremysnead
# Big Star: Nothing Can Hurt Me                   drewdenicola,oliviamori(co-director)
# Rams                                                                grímurhákonarson
# Maggie's Plan                                                          rebeccamiller
# Breadcrumb Trail                                                          lancebangs
# Last Train Home                                                             lixinfan
# The Wolfpack                                                          crystalmoselle
# Such Good People                                                         stewartwade
# 4 Moons                                                           sergiotovarvelarde
# Seashore                                             filipematzembacher,marcioreolon
#
#                                                                               Actors  \
# Title
# Rumble in the Bronx                        jackiechan,anitamui,françoiseyip,billtung
# Batman Forever                        valkilmer,tommyleejones,jimcarrey,nicolekidman
# Desperado                          antoniobanderas,salmahayek,joaquimdealmeida,ch...
# Die Hard: With a Vengeance         brucewillis,jeremyirons,samuell.jackson,graham...
# First Knight                            seanconnery,richardgere,juliaormond,bencross
# Mallrats                           shannendoherty,jeremylondon,jasonlee,clairefor...
# Clerks                             briano'halloran,jeffanderson,marilynghigliotti...
# Hot Shots! Part Deux               charliesheen,lloydbridges,valeriagolino,richar...
# Dead Man                           johnnydepp,garyfarmer,crispinglover,lancehenri...
# Die Hard 2                         brucewillis,bonniebedelia,williamatherton,regi...
# Batman Returns                     michaelkeaton,dannydevito,michellepfeiffer,chr...
# Donnie Brasco                           alpacino,johnnydepp,michaelmadsen,brunokirby
# Liar Liar                              jimcarrey,mauratierney,justincooper,caryelwes
# Grosse Pointe Blank                     johncusack,minniedriver,alanarkin,danaykroyd
# Face/Off                           johntravolta,nicolascage,joanallen,alessandron...
# City of Angels                         nicolascage,megryan,andrebraugher,dennisfranz
# Cube                               nicoledeboer,nickyguadagni,davidhewlett,andrew...
# Happiness                          janeadams,jonlovitz,philipseymourhoffman,dylan...
# American History X                 edwardnorton,edwardfurlong,beverlyd'angelo,jen...
# Enemy of the State                         willsmith,genehackman,jonvoight,lisabonet
# Office Space                       ronlivingston,jenniferaniston,davidherman,ajay...
# Wing Commander                     freddieprinzejr.,saffronburrows,matthewlillard...
# Ravenous                           guypearce,robertcarlyle,davidarquette,jeremyda...
# American Pie                       jasonbiggs,jennifercoolidge,shannonelizabeth,a...
# Boiler Room                               giovanniribisi,vindiesel,nialong,nickykatt
# Ghost Dog: The Way of the Samurai    forestwhitaker,johntormey,cliffgorman,dennisliu
# Requiem for a Dream                ellenburstyn,jaredleto,jenniferconnelly,marlon...
# Charlie's Angels                        camerondiaz,drewbarrymore,lucyliu,billmurray
# Dungeons & Dragons                  jeremyirons,brucepayne,justinwhalin,marlonwayans
# Valentine                          deniserichards,davidboreanaz,marleyshelton,jes...
# ...                                                                              ...
# Dadetown                                jimpryor,stephenbeals,fredworrell,edithmeeks
# Wheel of Time                      thedalailama,lamalhundupwoeser,taknajigmesangp...
# Romanzo Criminale                  kimrossistuart,annamouglalis,pierfrancescofavi...
# Far                                stéphanerideau,lubnaazabal,mohamedhamaidi,yasm...
# Heart of America                   jürgenprochnow,michaelparé,patrickmuldoon,kett...
# Special                            michaelrapaport,paulblackthorne,joshpeck,rober...
# Blackwoods                         patrickmuldoon,keeganconnortracy,willsanderson...
# Gunless                            paulgross,siennaguillory,dustinmilligan,tylermane
# Route Irish                               markwomack,andrealowe,johnbishop,geoffbell
# Reykjavik-Rotterdam                baltasarkormákur,ingvareggertsigurðsson,liljan...
# Hammer of the Gods                 charliebewley,clivestanden,jamescosmo,elliotcowan
# Child of God                         scotthaze,timblakenelson,jimparrack,stevehunter
# Last Will                          tatumo'neal,tomberenger,patrickmuldoon,peterco...
# Kill Your Friends                  nicholashoult,jamescorden,georgiaking,craigrob...
# Now You See It...                  alymichalka,johnnypacar,franklangella,chrisoli...
# War on Everyone                    alexanderskarsgård,michaelpeña,theojames,tessa...
# Eating Out 2: Sloppy Seconds       jimverraros,emilybrookehands,rebekahkochan,bre...
# Spin                               raymondandrewbailey,cesarbejarano,brandoncarri...
# Craigslist Joe                     josephgarner,kristosandrews,ginakeatley,michae...
# Living on One Dollar               christemple,zachingrasci,seanleonard,ryanchris...
# Video Games: The Movie             seanastin,alalcorn,peterarmstrong,cliffbleszinski
# Big Star: Nothing Can Hurt Me              billyaltman,jonauer,lesterbangs,chrisbell
# Rams                               sigurðursigurjónsson,theodórjúlíusson,charlott...
# Maggie's Plan                       gretagerwig,georgeashiotis,billhader,montegreene
# Breadcrumb Trail                    stevealbini,toddbrashear,ianmackaye,brianmcmahan
# Last Train Home                           changhuazhang,suqinchen,qinzhang,yangzhang
# The Wolfpack                       bhagavanangulo,govindaangulo,jagadisaangulo,kr...
# Such Good People                   michaelurie,randyharrison,jamesurbaniak,scottwolf
# 4 Moons                            antoniovelázquez,alejandrodelamadrid,cesarramo...
# Seashore                           mateusalmada,mauríciobarcellos,elisabrittes,fe...
#
#                                                                         bag_of_words
# Title
# Rumble in the Bronx                jackiechan anitamui françoiseyip billtung stan...
# Batman Forever                     valkilmer tommyleejones jimcarrey nicolekidman...
# Desperado                          antoniobanderas salmahayek joaquimdealmeida ch...
# Die Hard: With a Vengeance         brucewillis jeremyirons samuell.jackson graham...
# First Knight                       seanconnery richardgere juliaormond bencross j...
# Mallrats                           shannendoherty jeremylondon jasonlee clairefor...
# Clerks                             briano'halloran jeffanderson marilynghigliotti...
# Hot Shots! Part Deux               charliesheen lloydbridges valeriagolino richar...
# Dead Man                           johnnydepp garyfarmer crispinglover lancehenri...
# Die Hard 2                         brucewillis bonniebedelia williamatherton regi...
# Batman Returns                     michaelkeaton dannydevito michellepfeiffer chr...
# Donnie Brasco                      alpacino johnnydepp michaelmadsen brunokirby m...
# Liar Liar                          jimcarrey mauratierney justincooper caryelwes ...
# Grosse Pointe Blank                johncusack minniedriver alanarkin danaykroyd g...
# Face/Off                           johntravolta nicolascage joanallen alessandron...
# City of Angels                     nicolascage megryan andrebraugher dennisfranz ...
# Cube                               nicoledeboer nickyguadagni davidhewlett andrew...
# Happiness                          janeadams jonlovitz philipseymourhoffman dylan...
# American History X                 edwardnorton edwardfurlong beverlyd'angelo jen...
# Enemy of the State                 willsmith genehackman jonvoight lisabonet tony...
# Office Space                       ronlivingston jenniferaniston davidherman ajay...
# Wing Commander                     freddieprinzejr. saffronburrows matthewlillard...
# Ravenous                           guypearce robertcarlyle davidarquette jeremyda...
# American Pie                       jasonbiggs jennifercoolidge shannonelizabeth a...
# Boiler Room                        giovanniribisi vindiesel nialong nickykatt ben...
# Ghost Dog: The Way of the Samurai  forestwhitaker johntormey cliffgorman dennisli...
# Requiem for a Dream                ellenburstyn jaredleto jenniferconnelly marlon...
# Charlie's Angels                   camerondiaz drewbarrymore lucyliu billmurray m...
# Dungeons & Dragons                 jeremyirons brucepayne justinwhalin marlonwaya...
# Valentine                          deniserichards davidboreanaz marleyshelton jes...
# ...                                                                              ...
# Dadetown                           jimpryor stephenbeals fredworrell edithmeeks r...
# Wheel of Time                      thedalailama lamalhundupwoeser taknajigmesangp...
# Romanzo Criminale                  kimrossistuart annamouglalis pierfrancescofavi...
# Far                                stéphanerideau lubnaazabal mohamedhamaidi yasm...
# Heart of America                   jürgenprochnow michaelparé patrickmuldoon kett...
# Special                            michaelrapaport paulblackthorne joshpeck rober...
# Blackwoods                         patrickmuldoon keeganconnortracy willsanderson...
# Gunless                            paulgross siennaguillory dustinmilligan tylerm...
# Route Irish                        markwomack andrealowe johnbishop geoffbell ken...
# Reykjavik-Rotterdam                baltasarkormákur ingvareggertsigurðsson liljan...
# Hammer of the Gods                 charliebewley clivestanden jamescosmo elliotco...
# Child of God                       scotthaze timblakenelson jimparrack stevehunte...
# Last Will                          tatumo'neal tomberenger patrickmuldoon peterco...
# Kill Your Friends                  nicholashoult jamescorden georgiaking craigrob...
# Now You See It...                  alymichalka johnnypacar franklangella chrisoli...
# War on Everyone                    alexanderskarsgård michaelpeña theojames tessa...
# Eating Out 2: Sloppy Seconds       jimverraros emilybrookehands rebekahkochan bre...
# Spin                               raymondandrewbailey cesarbejarano brandoncarri...
# Craigslist Joe                     josephgarner kristosandrews ginakeatley michae...
# Living on One Dollar               christemple zachingrasci seanleonard ryanchris...
# Video Games: The Movie             seanastin alalcorn peterarmstrong cliffbleszin...
# Big Star: Nothing Can Hurt Me      billyaltman jonauer lesterbangs chrisbell drew...
# Rams                               sigurðursigurjónsson theodórjúlíusson charlott...
# Maggie's Plan                      gretagerwig georgeashiotis billhader montegree...
# Breadcrumb Trail                   stevealbini toddbrashear ianmackaye brianmcmah...
# Last Train Home                    changhuazhang suqinchen qinzhang yangzhang lix...
# The Wolfpack                       bhagavanangulo govindaangulo jagadisaangulo kr...
# Such Good People                   michaelurie randyharrison jamesurbaniak scottw...
# 4 Moons                            antoniovelázquez alejandrodelamadrid cesarramo...
# Seashore                           mateusalmada mauríciobarcellos elisabrittes fe...
#
# [7003 rows x 4 columns]

# %%
movies_bow = movies_df[['Title', 'bag_of_words']]

movies_bow.set_index('Title')
# Out:
#                                                                         bag_of_words
# Title
# Rumble in the Bronx                jackiechan anitamui françoiseyip billtung stan...
# Batman Forever                     valkilmer tommyleejones jimcarrey nicolekidman...
# Desperado                          antoniobanderas salmahayek joaquimdealmeida ch...
# Die Hard: With a Vengeance         brucewillis jeremyirons samuell.jackson graham...
# First Knight                       seanconnery richardgere juliaormond bencross j...
# Mallrats                           shannendoherty jeremylondon jasonlee clairefor...
# Clerks                             briano'halloran jeffanderson marilynghigliotti...
# Hot Shots! Part Deux               charliesheen lloydbridges valeriagolino richar...
# Dead Man                           johnnydepp garyfarmer crispinglover lancehenri...
# Die Hard 2                         brucewillis bonniebedelia williamatherton regi...
# Batman Returns                     michaelkeaton dannydevito michellepfeiffer chr...
# Donnie Brasco                      alpacino johnnydepp michaelmadsen brunokirby m...
# Liar Liar                          jimcarrey mauratierney justincooper caryelwes ...
# Grosse Pointe Blank                johncusack minniedriver alanarkin danaykroyd g...
# Face/Off                           johntravolta nicolascage joanallen alessandron...
# City of Angels                     nicolascage megryan andrebraugher dennisfranz ...
# Cube                               nicoledeboer nickyguadagni davidhewlett andrew...
# Happiness                          janeadams jonlovitz philipseymourhoffman dylan...
# American History X                 edwardnorton edwardfurlong beverlyd'angelo jen...
# Enemy of the State                 willsmith genehackman jonvoight lisabonet tony...
# Office Space                       ronlivingston jenniferaniston davidherman ajay...
# Wing Commander                     freddieprinzejr. saffronburrows matthewlillard...
# Ravenous                           guypearce robertcarlyle davidarquette jeremyda...
# American Pie                       jasonbiggs jennifercoolidge shannonelizabeth a...
# Boiler Room                        giovanniribisi vindiesel nialong nickykatt ben...
# Ghost Dog: The Way of the Samurai  forestwhitaker johntormey cliffgorman dennisli...
# Requiem for a Dream                ellenburstyn jaredleto jenniferconnelly marlon...
# Charlie's Angels                   camerondiaz drewbarrymore lucyliu billmurray m...
# Dungeons & Dragons                 jeremyirons brucepayne justinwhalin marlonwaya...
# Valentine                          deniserichards davidboreanaz marleyshelton jes...
# ...                                                                              ...
# Dadetown                           jimpryor stephenbeals fredworrell edithmeeks r...
# Wheel of Time                      thedalailama lamalhundupwoeser taknajigmesangp...
# Romanzo Criminale                  kimrossistuart annamouglalis pierfrancescofavi...
# Far                                stéphanerideau lubnaazabal mohamedhamaidi yasm...
# Heart of America                   jürgenprochnow michaelparé patrickmuldoon kett...
# Special                            michaelrapaport paulblackthorne joshpeck rober...
# Blackwoods                         patrickmuldoon keeganconnortracy willsanderson...
# Gunless                            paulgross siennaguillory dustinmilligan tylerm...
# Route Irish                        markwomack andrealowe johnbishop geoffbell ken...
# Reykjavik-Rotterdam                baltasarkormákur ingvareggertsigurðsson liljan...
# Hammer of the Gods                 charliebewley clivestanden jamescosmo elliotco...
# Child of God                       scotthaze timblakenelson jimparrack stevehunte...
# Last Will                          tatumo'neal tomberenger patrickmuldoon peterco...
# Kill Your Friends                  nicholashoult jamescorden georgiaking craigrob...
# Now You See It...                  alymichalka johnnypacar franklangella chrisoli...
# War on Everyone                    alexanderskarsgård michaelpeña theojames tessa...
# Eating Out 2: Sloppy Seconds       jimverraros emilybrookehands rebekahkochan bre...
# Spin                               raymondandrewbailey cesarbejarano brandoncarri...
# Craigslist Joe                     josephgarner kristosandrews ginakeatley michae...
# Living on One Dollar               christemple zachingrasci seanleonard ryanchris...
# Video Games: The Movie             seanastin alalcorn peterarmstrong cliffbleszin...
# Big Star: Nothing Can Hurt Me      billyaltman jonauer lesterbangs chrisbell drew...
# Rams                               sigurðursigurjónsson theodórjúlíusson charlott...
# Maggie's Plan                      gretagerwig georgeashiotis billhader montegree...
# Breadcrumb Trail                   stevealbini toddbrashear ianmackaye brianmcmah...
# Last Train Home                    changhuazhang suqinchen qinzhang yangzhang lix...
# The Wolfpack                       bhagavanangulo govindaangulo jagadisaangulo kr...
# Such Good People                   michaelurie randyharrison jamesurbaniak scottw...
# 4 Moons                            antoniovelázquez alejandrodelamadrid cesarramo...
# Seashore                           mateusalmada mauríciobarcellos elisabrittes fe...
#
# [7003 rows x 1 columns]

# %%
movies_bow.set_index('Title')
# Out:
#                                                                         bag_of_words
# Title
# Rumble in the Bronx                jackiechan anitamui françoiseyip billtung stan...
# Batman Forever                     valkilmer tommyleejones jimcarrey nicolekidman...
# Desperado                          antoniobanderas salmahayek joaquimdealmeida ch...
# Die Hard: With a Vengeance         brucewillis jeremyirons samuell.jackson graham...
# First Knight                       seanconnery richardgere juliaormond bencross j...
# Mallrats                           shannendoherty jeremylondon jasonlee clairefor...
# Clerks                             briano'halloran jeffanderson marilynghigliotti...
# Hot Shots! Part Deux               charliesheen lloydbridges valeriagolino richar...
# Dead Man                           johnnydepp garyfarmer crispinglover lancehenri...
# Die Hard 2                         brucewillis bonniebedelia williamatherton regi...
# Batman Returns                     michaelkeaton dannydevito michellepfeiffer chr...
# Donnie Brasco                      alpacino johnnydepp michaelmadsen brunokirby m...
# Liar Liar                          jimcarrey mauratierney justincooper caryelwes ...
# Grosse Pointe Blank                johncusack minniedriver alanarkin danaykroyd g...
# Face/Off                           johntravolta nicolascage joanallen alessandron...
# City of Angels                     nicolascage megryan andrebraugher dennisfranz ...
# Cube                               nicoledeboer nickyguadagni davidhewlett andrew...
# Happiness                          janeadams jonlovitz philipseymourhoffman dylan...
# American History X                 edwardnorton edwardfurlong beverlyd'angelo jen...
# Enemy of the State                 willsmith genehackman jonvoight lisabonet tony...
# Office Space                       ronlivingston jenniferaniston davidherman ajay...
# Wing Commander                     freddieprinzejr. saffronburrows matthewlillard...
# Ravenous                           guypearce robertcarlyle davidarquette jeremyda...
# American Pie                       jasonbiggs jennifercoolidge shannonelizabeth a...
# Boiler Room                        giovanniribisi vindiesel nialong nickykatt ben...
# Ghost Dog: The Way of the Samurai  forestwhitaker johntormey cliffgorman dennisli...
# Requiem for a Dream                ellenburstyn jaredleto jenniferconnelly marlon...
# Charlie's Angels                   camerondiaz drewbarrymore lucyliu billmurray m...
# Dungeons & Dragons                 jeremyirons brucepayne justinwhalin marlonwaya...
# Valentine                          deniserichards davidboreanaz marleyshelton jes...
# ...                                                                              ...
# Dadetown                           jimpryor stephenbeals fredworrell edithmeeks r...
# Wheel of Time                      thedalailama lamalhundupwoeser taknajigmesangp...
# Romanzo Criminale                  kimrossistuart annamouglalis pierfrancescofavi...
# Far                                stéphanerideau lubnaazabal mohamedhamaidi yasm...
# Heart of America                   jürgenprochnow michaelparé patrickmuldoon kett...
# Special                            michaelrapaport paulblackthorne joshpeck rober...
# Blackwoods                         patrickmuldoon keeganconnortracy willsanderson...
# Gunless                            paulgross siennaguillory dustinmilligan tylerm...
# Route Irish                        markwomack andrealowe johnbishop geoffbell ken...
# Reykjavik-Rotterdam                baltasarkormákur ingvareggertsigurðsson liljan...
# Hammer of the Gods                 charliebewley clivestanden jamescosmo elliotco...
# Child of God                       scotthaze timblakenelson jimparrack stevehunte...
# Last Will                          tatumo'neal tomberenger patrickmuldoon peterco...
# Kill Your Friends                  nicholashoult jamescorden georgiaking craigrob...
# Now You See It...                  alymichalka johnnypacar franklangella chrisoli...
# War on Everyone                    alexanderskarsgård michaelpeña theojames tessa...
# Eating Out 2: Sloppy Seconds       jimverraros emilybrookehands rebekahkochan bre...
# Spin                               raymondandrewbailey cesarbejarano brandoncarri...
# Craigslist Joe                     josephgarner kristosandrews ginakeatley michae...
# Living on One Dollar               christemple zachingrasci seanleonard ryanchris...
# Video Games: The Movie             seanastin alalcorn peterarmstrong cliffbleszin...
# Big Star: Nothing Can Hurt Me      billyaltman jonauer lesterbangs chrisbell drew...
# Rams                               sigurðursigurjónsson theodórjúlíusson charlott...
# Maggie's Plan                      gretagerwig georgeashiotis billhader montegree...
# Breadcrumb Trail                   stevealbini toddbrashear ianmackaye brianmcmah...
# Last Train Home                    changhuazhang suqinchen qinzhang yangzhang lix...
# The Wolfpack                       bhagavanangulo govindaangulo jagadisaangulo kr...
# Such Good People                   michaelurie randyharrison jamesurbaniak scottw...
# 4 Moons                            antoniovelázquez alejandrodelamadrid cesarramo...
# Seashore                           mateusalmada mauríciobarcellos elisabrittes fe...
#
# [7003 rows x 1 columns]

# %%
# Import sklearn models

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# instantiating and generating the count matrix
count = CountVectorizer()
count_matrix = count.fit_transform(movies_bow['bag_of_words'])


# generating the cosine similarity matrix
cosine_sim = cosine_similarity(count_matrix, count_matrix)

# %%
indices = pd.Series(movies_bow.index, index = movies_bow['Title'])

def get_recommendations(title, cosine_sim=cosine_sim):
    # Get the index of the movie that matches the title
    idx = indices[title]

    # Get the pairwsie similarity scores of all movies with that movie
    sim_scores = list(enumerate(cosine_sim[idx]))

    # Sort the movies based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the scores of the 10 most similar movies
    sim_scores = sim_scores[1:11]

    # Get the movie indices
    movie_indices = [i[0] for i in sim_scores]

    # Return the top 10 most similar movies
    return movies_bow['Title'].iloc[movie_indices]

# %%
# # Convert movie titles to numerical so they are associated to an ordered numerical. store in a series
# # This will be used in the function to match the indexes of the movies

# indices = pd.Series(movies_df.index)

# #  defining the function that takes in movie title 
# # as input and returns the top 10 recommended movies
# def recommendations(title, cosine_sim = cosine_sim):
    
#     # initializing the empty list of recommended movies
#     recommended_movies = []
    
#     # gettin the index of the movie that matches the title
#     idx = indices[indices == title].index[0]

#     # creating a Series with the similarity scores in descending order
#     score_series = pd.Series(cosine_sim[idx]).sort_values(ascending = False)

#     # getting the indexes of the 10 most similar movies
#     top_10_indexes = list(score_series.iloc[1:11].index)
    
#     # populating the list with the titles of the best 10 matching movies
#     for i in top_10_indexes:
#         recommended_movies.append(list(movies_df.index)[i])
        
#     return recommended_movies

# %%
get_recommendations('Last Will')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-170-8a1a5cfeecc9> in <module>()
# ----> 1 get_recommendations('Last Will')
#
# <ipython-input-168-c1b3ecb14bea> in get_recommendations(title, cosine_sim)
#       6
#       7     # Get the pairwsie similarity scores of all movies with that movie
# ----> 8     sim_scores = list(enumerate(cosine_sim[idx]))
#       9
#      10     # Sort the movies based on the similarity scores
#
# IndexError: index 774572 is out of bounds for axis 0 with size 7003

# %%
indices
# Out:
# Title
# Rumble in the Bronx                       0
# Batman Forever                          831
# Desperado                              3098
# Die Hard: With a Vengeance             4099
# First Knight                           8967
# Mallrats                              10088
# Clerks                                10493
# Hot Shots! Part Deux                  12244
# Dead Man                              13290
# Die Hard 2                            13465
# Batman Returns                        14097
# Donnie Brasco                         14502
# Liar Liar                             14937
# Grosse Pointe Blank                   15716
# Face/Off                              16300
# City of Angels                        17175
# Cube                                  17371
# Happiness                             17613
# American History X                    17957
# Enemy of the State                    19928
# Office Space                          20625
# Wing Commander                        21996
# Ravenous                              22043
# American Pie                          22095
# Boiler Room                           23468
# Ghost Dog: The Way of the Samurai     23694
# Requiem for a Dream                   23970
# Charlie's Angels                      25204
# Dungeons & Dragons                    26047
# Valentine                             26254
#                                       ...
# Dadetown                             774560
# Wheel of Time                        774561
# Romanzo Criminale                    774562
# Far                                  774563
# Heart of America                     774564
# Special                              774565
# Blackwoods                           774566
# Gunless                              774567
# Route Irish                          774568
# Reykjavik-Rotterdam                  774569
# Hammer of the Gods                   774570
# Child of God                         774571
# Last Will                            774572
# Kill Your Friends                    774573
# Now You See It...                    774574
# War on Everyone                      774575
# Eating Out 2: Sloppy Seconds         774576
# Spin                                 774577
# Craigslist Joe                       774581
# Living on One Dollar                 774582
# Video Games: The Movie               774583
# Big Star: Nothing Can Hurt Me        774584
# Rams                                 774585
# Maggie's Plan                        774586
# Breadcrumb Trail                     774587
# Last Train Home                      774588
# The Wolfpack                         774589
# Such Good People                     774590
# 4 Moons                              774591
# Seashore                             774592
# Length: 7003, dtype: int64
