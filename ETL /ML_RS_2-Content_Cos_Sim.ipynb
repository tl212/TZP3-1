# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Prepare Movie Data

# %%
# import dataset from movie_lens and omdb
#movie_lens data contains the columns movieId, genre, movie_nm, released
#omdb data contains title, actors, directors, year

movies_ml = pd.read_csv('data/movies_clean.csv')
movies_omdb = pd.read_csv('data/all_movies_info.csv')

# %%
movies_ml.head()
# Out:
#    movieId                                       genres  \
# 0        1  Adventure|Animation|Children|Comedy|Fantasy
# 1        2                   Adventure|Children|Fantasy
# 2        3                               Comedy|Romance
# 3        4                         Comedy|Drama|Romance
# 4        5                                       Comedy
#
#                        movie_nm  released
# 0                    Toy Story       1995
# 1                      Jumanji       1995
# 2             Grumpier Old Men       1995
# 3            Waiting to Exhale       1995
# 4  Father of the Bride Part II       1995

# %%
movies_omdb.head()
# Out:
#                  Title                                             Actors  \
# 0           Home Alone  Macaulay Culkin, Joe Pesci, Daniel Stern, John...
# 1                Ghost  Patrick Swayze, Demi Moore, Tony Goldwyn, Stan...
# 2   Dances with Wolves  Kevin Costner, Mary McDonnell, Graham Greene, ...
# 3         Pretty Woman  Richard Gere, Julia Roberts, Ralph Bellamy, Ja...
# 4  I, the Worst of All  Assumpta Serna, Dominique Sanda, Héctor Alteri...
#
#               Director  Year
# 0       Chris Columbus  1990
# 1         Jerry Zucker  1990
# 2        Kevin Costner  1990
# 3       Garry Marshall  1990
# 4  María Luisa Bemberg  1990

# %%
# prepare both datasets to be joined on the Title column

# rename movie_nm to Title in movies_ml dataframe

movies_ml = movies_ml.rename(columns = {'movie_nm': 'Title'})

# apply strip method on the title columns of both datasets 

movies_ml['Title'] = movies_ml['Title'].str.strip()
movies_omdb['Title'] = movies_omdb['Title'].str.strip()

# %%
# complete join of dataframes

movies = pd.merge(movies_ml, movies_omdb, how = 'inner',on = 'Title' )

movies.shape
# Out:
# (31779, 7)

# %%
all_movies = movies.copy()

# %%
all_movies = all_movies[['movieId', 'Title', 'genres', 'released', 'Actors', 'Director']]

all_movies.head()
# Out:
#    movieId                        Title  \
# 0        1                    Toy Story
# 1        2                      Jumanji
# 2        3             Grumpier Old Men
# 3        4            Waiting to Exhale
# 4        5  Father of the Bride Part II
#
#                                         genres  released  \
# 0  Adventure|Animation|Children|Comedy|Fantasy      1995
# 1                   Adventure|Children|Fantasy      1995
# 2                               Comedy|Romance      1995
# 3                         Comedy|Drama|Romance      1995
# 4                                       Comedy      1995
#
#                                               Actors         Director
# 0      Tom Hanks, Tim Allen, Don Rickles, Jim Varney    John Lasseter
# 1  Robin Williams, Jonathan Hyde, Kirsten Dunst, ...     Joe Johnston
# 2  Walter Matthau, Jack Lemmon, Sophia Loren, Ann...    Howard Deutch
# 3  Whitney Houston, Angela Bassett, Loretta Devin...  Forest Whitaker
# 4  Steve Martin, Diane Keaton, Martin Short, Kimb...    Charles Shyer

# %% [markdown]
# #### Prepare Ratings Data

# %%
ratings = pd.read_csv('data/ratings.csv')

# %%
print(ratings.shape)
ratings.head()
# Out:
# (26024289, 4)
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %% [markdown]
# #### Reduce the size of ratings dataframe
#
# To reduce the size of the ratings dataframe we needed to decide on a meaningful way to shrink the data. We conducted exploratory analysis and decided to split the data based on users who rated within a range of the mean number of ratings per user.

# %%
# count number of ratings per user
user_ratings_grp = pd.DataFrame(ratings.groupby('userId')['rating'].count())

# %%
user_ratings_grp.head()
# Out:
#         rating
# userId
# 1           27
# 2           22
# 3           10
# 4           62
# 5           26

# %%
user_ratings_grp.describe()
# Out:
#               rating
# count  270896.000000
# mean       96.067454
# std       205.719606
# min         1.000000
# 25%        15.000000
# 50%        30.000000
# 75%        93.000000
# max     18276.000000

# %%
# find mean of number of ratings per user
avg_nratings = user_ratings_grp['rating'].mean()

avg_nratings
# Out:
# 96.06745393065974

# %%
# find mean number of ratings per movie. This will be used to limit the results when the similarity scores 
# are calculated
movie_ratings_grp = pd.DataFrame(ratings.groupby('movieId')['rating'].count())

# %%
movie_ratings_grp.describe()
# Out:
#              rating
# count  45115.000000
# mean     576.843378
# std     3037.380582
# min        1.000000
# 25%        2.000000
# 50%        8.000000
# 75%       69.000000
# max    91921.000000

# %%
movie_ratings_grp.head()
# Out:
#          rating
# movieId
# 1         66008
# 2         26060
# 3         15497
# 4          2981
# 5         15258

# %%
# find users who rated within +10 or - 10 of the mean

avg_activity = user_ratings_grp[(user_ratings_grp['rating'] >= 85) & (user_ratings_grp['rating'] <= 150)]
print(avg_activity.shape)

# rename column

avg_activity = avg_activity.rename(columns = {'rating': 'rating_ct'})

avg_activity.head()
# Out:
# (28711, 1)
#         rating_ct
# userId
# 8             113
# 30            120
# 53            145
# 55            133
# 60            105

# %%
# # find users who rated over 

# avg_activity = user_ratings_grp[user_ratings_grp['rating'] >= 500]
# print(avg_activity.shape)

# # rename column

# avg_activity = avg_activity.rename(columns = {'rating': 'rating_ct'})

# avg_activity.head()
# Out:
# (9516, 1)
#         rating_ct
# userId
# 24            634
# 46            766
# 120           516
# 132           572
# 150           585

# %%
# combine avg_activity and ratings to only return the ratings for the people that are 
#in the avg_activity dataframe

new_ratings = pd.merge(avg_activity, ratings, how = 'inner', on = 'userId')

print(new_ratings.shape)
new_ratings.head()
# Out:
# (3245584, 5)
#    userId  rating_ct  movieId  rating   timestamp
# 0       8        113        1     4.0  1013443596
# 1       8        113        7     2.0  1013442976
# 2       8        113       44     3.0  1013442518
# 3       8        113       47     4.0  1013443770
# 4       8        113      170     3.0  1013442544

# %% [markdown]
# Combine Ratings and Movies Dataset

# %%
mrd = pd.merge(new_ratings, all_movies,how = 'inner', on = 'movieId')

# %%
print(mrd.shape)
mrd.head()
# Out:
# (2186279, 10)
#    userId  rating_ct  movieId  rating   timestamp      Title  \
# 0       8        113        1     4.0  1013443596  Toy Story
# 1      55        133        1     5.0  1037743445  Toy Story
# 2      63        113        1     3.5  1198546021  Toy Story
# 3      74        143        1     5.0   862777274  Toy Story
# 4      76        105        1     3.5  1322344481  Toy Story
#
#                                         genres  released  \
# 0  Adventure|Animation|Children|Comedy|Fantasy      1995
# 1  Adventure|Animation|Children|Comedy|Fantasy      1995
# 2  Adventure|Animation|Children|Comedy|Fantasy      1995
# 3  Adventure|Animation|Children|Comedy|Fantasy      1995
# 4  Adventure|Animation|Children|Comedy|Fantasy      1995
#
#                                           Actors       Director
# 0  Tom Hanks, Tim Allen, Don Rickles, Jim Varney  John Lasseter
# 1  Tom Hanks, Tim Allen, Don Rickles, Jim Varney  John Lasseter
# 2  Tom Hanks, Tim Allen, Don Rickles, Jim Varney  John Lasseter
# 3  Tom Hanks, Tim Allen, Don Rickles, Jim Varney  John Lasseter
# 4  Tom Hanks, Tim Allen, Don Rickles, Jim Varney  John Lasseter

# %%
# check for nulls

mrd.isnull().sum()
# Out:
# userId       0
# rating_ct    0
# movieId      0
# rating       0
# timestamp    0
# Title        0
# genres       0
# released     0
# Actors       0
# Director     0
# dtype: int64

# %%
mrd.groupby('Title')['rating'].mean().head()
# Out:
# Title
# $5 a Day                            4.000000
# $9.99                               3.166667
# '71                                 3.900000
# 'Hellboy': The Seeds of Creation    3.447368
# 'Til There Was You                  3.201754
# Name: rating, dtype: float64

# %%
mrd.groupby('Title')['rating'].mean().sort_values(ascending=False).head()
# Out:
# Title
# Unconditional Love      5.0
# Born Romantic           5.0
# Shaitan                 5.0
# Jack Goes Boating       5.0
# It's a Free World...    5.0
# Name: rating, dtype: float64

# %%
mrd.groupby('Title')['rating'].count().sort_values(ascending=False).head()
# Out:
# Title
# Beauty and the Beast          26960
# Terminator 2: Judgment Day    24842
# Ghost                         23216
# Gladiator                     17894
# Iron Man                      17268
# Name: rating, dtype: int64

# %%
ratingsMeanCount = pd.DataFrame(mrd.groupby('Title')['rating'].mean())
ratingsMeanCount.head()
# Out:
#                                     rating
# Title
# $5 a Day                          4.000000
# $9.99                             3.166667
# '71                               3.900000
# 'Hellboy': The Seeds of Creation  3.447368
# 'Til There Was You                3.201754

# %%
ratingsMeanCount['ratingsCounts'] = pd.DataFrame(mrd.groupby('Title')['rating'].count())
ratingsMeanCount.head()
# Out:
#                                     rating  ratingsCounts
# Title
# $5 a Day                          4.000000              1
# $9.99                             3.166667              6
# '71                               3.900000             10
# 'Hellboy': The Seeds of Creation  3.447368             19
# 'Til There Was You                3.201754             57

# %%
user_movie_rating = mrd.pivot_table(index='userId', columns='Title', values='rating')

# %%
user_movie_rating.head()
# Out:
# Title   $5 a Day  $9.99  '71  'Hellboy': The Seeds of Creation  \
# userId
# 8            NaN    NaN  NaN                               NaN
# 30           NaN    NaN  NaN                               NaN
# 53           NaN    NaN  NaN                               NaN
# 55           NaN    NaN  NaN                               NaN
# 60           NaN    NaN  NaN                               NaN
#
# Title   'Til There Was You  00 Schneider - Jagd auf Nihil Baxter  \
# userId
# 8                      NaN                                   NaN
# 30                     NaN                                   NaN
# 53                     NaN                                   NaN
# 55                     NaN                                   NaN
# 60                     NaN                                   NaN
#
# Title   009 Re: Cyborg  10 Cloverfield Lane  10 Items or Less  \
# userId
# 8                  NaN                  NaN               NaN
# 30                 NaN                  NaN               NaN
# 53                 NaN                  NaN               NaN
# 55                 NaN                  NaN               NaN
# 60                 NaN                  NaN               NaN
#
# Title   10 Questions for the Dalai Lama           ...             Zuzu Angel  \
# userId                                            ...
# 8                                   NaN           ...                    NaN
# 30                                  NaN           ...                    NaN
# 53                                  NaN           ...                    NaN
# 55                                  NaN           ...                    NaN
# 60                                  NaN           ...                    NaN
#
# Title   Zygote  [REC] 4: Apocalypse  eXistenZ  iBoy  iMurders  \
# userId
# 8          NaN                  NaN       2.0   NaN       NaN
# 30         NaN                  NaN       2.0   NaN       NaN
# 53         NaN                  NaN       NaN   NaN       NaN
# 55         NaN                  NaN       NaN   NaN       NaN
# 60         NaN                  NaN       NaN   NaN       NaN
#
# Title   loudQUIETloud: A Film About the Pixies  xXx  \
# userId
# 8                                          NaN  NaN
# 30                                         NaN  NaN
# 53                                         NaN  NaN
# 55                                         NaN  NaN
# 60                                         NaN  NaN
#
# Title   xXx: Return of Xander Cage  xXx: State of the Union
# userId
# 8                              NaN                      NaN
# 30                             NaN                      NaN
# 53                             NaN                      NaN
# 55                             NaN                      NaN
# 60                             NaN                      NaN
#
# [5 rows x 9036 columns]

# %% [markdown]
# ####  Perform Collaborative Filtering
#
# In this section we will find the similarity between movies based on user ratings. First we will run the series of steps on one movie to ensure that the code works at every level. Then, the code will be compiled into a function.

# %%
# find all the users who rated a movie. 

testing_ratings = user_movie_rating['Toy Story']
testing_ratings.head()
# Out:
# userId
# 8     4.0
# 30    NaN
# 53    NaN
# 55    5.0
# 60    NaN
# Name: Toy Story, dtype: float64

# %%
movies_like_toyStory = user_movie_rating.corrwith(testing_ratings)

corr_ts = pd.DataFrame(movies_like_toyStory, columns=['Correlation'])  
corr_ts.dropna(inplace=True)  
corr_ts.head(10)
# Out:
# C:\Users\zkxav\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2392: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# C:\Users\zkxav\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2326: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
#                                   Correlation
# Title
# 'Hellboy': The Seeds of Creation     0.208623
# 'Til There Was You                  -0.033811
# 10 Cloverfield Lane                  0.332993
# 10 Items or Less                     0.053483
# 10 Things I Hate About You           0.087516
# 10,000 BC                           -0.009693
# 100 Feet                            -1.000000
# 100 Girls                            0.029156
# 101 Dalmatians                       0.322301
# 102 Dalmatians                       0.175695

# %%
# Rearrenge the correlational outcome we computed above in descending order

corr_ts.sort_values('Correlation', ascending=False).head(10)
# Out:
#                                   Correlation
# Title
# Tube Tales                                1.0
# All the Queen's Men                       1.0
# Mind Game                                 1.0
# Raw                                       1.0
# American Me                               1.0
# We Are the Best!                          1.0
# Ratcatcher                                1.0
# A Ghost Story                             1.0
# King Arthur: Legend of the Sword          1.0
# Love the Beast                            1.0

# %%
corr_ts.reset_index(inplace=True)
corr_ts.head()
# Out:
#                               Title  Correlation
# 0  'Hellboy': The Seeds of Creation     0.208623
# 1                'Til There Was You    -0.033811
# 2               10 Cloverfield Lane     0.332993
# 3                  10 Items or Less     0.053483
# 4        10 Things I Hate About You     0.087516

# %%
corr_ts.count()
# Out:
# Title          4584
# Correlation    4584
# dtype: int64

# %%
# Improve results by eliminating movies that have a low number of ratings.

corr_ts = corr_ts.merge(ratingsMeanCount, on='Title', how='inner') 
corr_ts.head()
# Out:
#                               Title  Correlation    rating  ratingsCounts
# 0  'Hellboy': The Seeds of Creation     0.208623  3.447368             19
# 1                'Til There Was You    -0.033811  3.201754             57
# 2               10 Cloverfield Lane     0.332993  3.742775            173
# 3                  10 Items or Less     0.053483  3.014286             35
# 4        10 Things I Hate About You     0.087516  3.598327           3946

# %%
corr_ts = corr_ts.drop(['rating'], axis=1)
corr_ts.head()
# Out:
#                               Title  Correlation  ratingsCounts
# 0  'Hellboy': The Seeds of Creation     0.208623             19
# 1                'Til There Was You    -0.033811             57
# 2               10 Cloverfield Lane     0.332993            173
# 3                  10 Items or Less     0.053483             35
# 4        10 Things I Hate About You     0.087516           3946

# %%
corr_ts[corr_ts ['ratingsCounts']>50].sort_values('Correlation', ascending=False).head()
# Out:
#           Title  Correlation  ratingsCounts
# 4172  Toy Story     1.000000          11055
# 2574        Max     1.000000             80
# 4222     Trumbo     1.000000             54
# 2024    Inferno     0.970143             54
# 313      August     0.884652             60

# %%
# function compiled from all the previous steps

def rec_movies(movie):
    top_10 = []
    curr_movie = user_movie_rating[movie]
    curr_movie_results = user_movie_rating.corrwith(curr_movie)
    corr_df = pd.DataFrame(curr_movie_results, columns=['Correlation'])  
    corr_df.dropna(inplace=True)  
    corr_df = corr_df.sort_values('Correlation', ascending=False) 
    corr_df.reset_index(inplace=True)
    corr_df = corr_df.merge(ratingsMeanCount, on='Title', how='inner') 
    rec_results = corr_df[corr_df ['ratingsCounts']>50].sort_values('Correlation', ascending=False)
    top_10 = rec_results[:10]
    return top_10

# %%
rec_movies('Toy Story')
# Out:
# C:\Users\zkxav\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2392: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# C:\Users\zkxav\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2326: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
#                        Title  Correlation    rating  ratingsCounts
# 50                 Toy Story     1.000000  3.919313          11055
# 230                      Max     1.000000  3.562500             80
# 235                   Trumbo     1.000000  3.796296             54
# 259                  Inferno     0.970143  3.722222             54
# 320                   August     0.884652  3.000000             60
# 353  Lee Daniels' The Butler     0.852803  3.879310             58
# 366                    Cargo     0.827144  3.382353             85
# 372               The Island     0.814862  3.750000             52
# 384          Head Over Heels     0.792458  3.397436            117
# 395            Inherent Vice     0.778784  3.362745             51

# %% [markdown]
# ### Content Recommendation System

# %%
movies_only = mrd[['Title','genres','Director','Actors']]

# %%
movies_only.shape
# Out:
# (2186279, 4)

# %%
movies_only.drop_duplicates(inplace = True)
# Out:
# C:\Users\zkxav\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
movies_only.isnull().sum()
# Out:
# Title       0
# genres      0
# Director    0
# Actors      0
# dtype: int64

# %%
movies_only.shape
# Out:
# (9264, 4)

# %%
movies_only.head()
# Out:
#                Title                                       genres  \
# 0          Toy Story  Adventure|Animation|Children|Comedy|Fantasy
# 11055        Sabrina                               Comedy|Romance
# 13181  Mortal Kombat                     Action|Adventure|Fantasy
# 15309        Hackers              Action|Adventure|Crime|Thriller
# 16798     Waterworld                      Action|Adventure|Sci-Fi
#
#                  Director                                             Actors
# 0           John Lasseter      Tom Hanks, Tim Allen, Don Rickles, Jim Varney
# 11055        Billy Wilder  Humphrey Bogart, Audrey Hepburn, William Holde...
# 13181  Paul W.S. Anderson  Christopher Lambert, Robin Shou, Linden Ashby,...
# 15309        Iain Softley  Jonny Lee Miller, Angelina Jolie, Jesse Bradfo...
# 16798      Kevin Reynolds  Kevin Costner, Chaim Jeraffi, Rick Aviles, R.D...

# %%
movies_only.to_csv('data/movies_only.csv', index = False)

# %% [markdown]
# Content System based on Cosine Similarity

# %%
movies_df = movies_only.copy()

# %%
# Clean data

# remove spaces from actors and director names so that the system will not mix up actors or directors
# where the first name or last name matches

def clean_data(x):
    if isinstance(x, list):
        return[str.lower(i.replace(" ", "")) for i in x]
    else:
        if isinstance(x, str):
            return str.lower(x.replace(" ", ""))
        else:
            return ''

# %%
credits = ['Actors', 'Director']

# apply function to each column

for credit in credits:
    movies_df[credit] = movies_df[credit].apply(clean_data)
    
movies_df.head()
# Out:
#                Title                                       genres  \
# 0          Toy Story  Adventure|Animation|Children|Comedy|Fantasy
# 11055        Sabrina                               Comedy|Romance
# 13181  Mortal Kombat                     Action|Adventure|Fantasy
# 15309        Hackers              Action|Adventure|Crime|Thriller
# 16798     Waterworld                      Action|Adventure|Sci-Fi
#
#                Director                                             Actors
# 0          johnlasseter             tomhanks,timallen,donrickles,jimvarney
# 11055       billywilder  humphreybogart,audreyhepburn,williamholden,wal...
# 13181  paulw.s.anderson  christopherlambert,robinshou,lindenashby,cary-...
# 15309       iainsoftley  jonnyleemiller,angelinajolie,jessebradford,mat...
# 16798     kevinreynolds      kevincostner,chaimjeraffi,rickaviles,r.d.call

# %%
genres = movies_df['genres'].str.get_dummies(sep ='|')

# %%
actors = movies_df['Actors'].str.get_dummies(sep = ',')

# %%
actors.head()
# Out:
#        'snub'pollard  50cent  7yearbitch  a.j.cook  a.j.langer  \
# 0                  0       0           0         0           0
# 11055              0       0           0         0           0
# 13181              0       0           0         0           0
# 15309              0       0           0         0           0
# 16798              0       0           0         0           0
#
#        a.michaelbaldwin  aaliyah  aamirkhan  aaranthomas  aarneaksila  \
# 0                     0        0          0            0            0
# 11055                 0        0          0            0            0
# 13181                 0        0          0            0            0
# 15309                 0        0          0            0            0
# 16798                 0        0          0            0            0
#
#                ...            óscarjaenada  özgeözberk  özgünamal  özkanugur  \
# 0              ...                       0           0          0          0
# 11055          ...                       0           0          0          0
# 13181          ...                       0           0          0          0
# 15309          ...                       0           0          0          0
# 16798          ...                       0           0          0          0
#
#        öznurkula  ørjangamst  øyvinbangberven  úlfurægisson  \
# 0              0           0                0             0
# 11055          0           0                0             0
# 13181          0           0                0             0
# 15309          0           0                0             0
# 16798          0           0                0             0
#
#        þrösturleógunnarsson  þrúðurkristjánsdóttir
# 0                         0                      0
# 11055                     0                      0
# 13181                     0                      0
# 15309                     0                      0
# 16798                     0                      0
#
# [5 rows x 18291 columns]

# %%
# join genres the main dataframe

movies_w_gdummies = pd.merge(movies_df, genres, how = 'inner', left_index = True, right_index = True)

# %%
# join actors to the movies_w_gdummies_df

movies_w_dummies = pd.merge(movies_w_gdummies, actors, how = 'inner', left_index = True, right_index = True)

# %%
movies_w_dummies.head()
# Out:
#                Title                                       genres  \
# 0          Toy Story  Adventure|Animation|Children|Comedy|Fantasy
# 11055        Sabrina                               Comedy|Romance
# 13181  Mortal Kombat                     Action|Adventure|Fantasy
# 15309        Hackers              Action|Adventure|Crime|Thriller
# 16798     Waterworld                      Action|Adventure|Sci-Fi
#
#                Director                                             Actors  \
# 0          johnlasseter             tomhanks,timallen,donrickles,jimvarney
# 11055       billywilder  humphreybogart,audreyhepburn,williamholden,wal...
# 13181  paulw.s.anderson  christopherlambert,robinshou,lindenashby,cary-...
# 15309       iainsoftley  jonnyleemiller,angelinajolie,jessebradford,mat...
# 16798     kevinreynolds      kevincostner,chaimjeraffi,rickaviles,r.d.call
#
#        (no genres listed)  Action  Adventure  Animation  Children  Comedy  \
# 0                       0       0          1          1         1       1
# 11055                   0       0          0          0         0       1
# 13181                   0       1          1          0         0       0
# 15309                   0       1          1          0         0       0
# 16798                   0       1          1          0         0       0
#
#                ...            óscarjaenada  özgeözberk  özgünamal  özkanugur  \
# 0              ...                       0           0          0          0
# 11055          ...                       0           0          0          0
# 13181          ...                       0           0          0          0
# 15309          ...                       0           0          0          0
# 16798          ...                       0           0          0          0
#
#        öznurkula  ørjangamst  øyvinbangberven  úlfurægisson  \
# 0              0           0                0             0
# 11055          0           0                0             0
# 13181          0           0                0             0
# 15309          0           0                0             0
# 16798          0           0                0             0
#
#        þrösturleógunnarsson  þrúðurkristjánsdóttir
# 0                         0                      0
# 11055                     0                      0
# 13181                     0                      0
# 15309                     0                      0
# 16798                     0                      0
#
# [5 rows x 18315 columns]

# %%
movie_dummies = movies_w_dummies.copy()

# %%
movie_dummies.drop(['genres', 'Actors', '(no genres listed)'], axis=1, inplace =True)

# %%
movie_dummies.head()
# Out:
#                Title          Director  Action  Adventure  Animation  \
# 0          Toy Story      johnlasseter       0          1          1
# 11055        Sabrina       billywilder       0          0          0
# 13181  Mortal Kombat  paulw.s.anderson       1          1          0
# 15309        Hackers       iainsoftley       1          1          0
# 16798     Waterworld     kevinreynolds       1          1          0
#
#        Children  Comedy  Crime  Documentary  Drama            ...             \
# 0             1       1      0            0      0            ...
# 11055         0       1      0            0      0            ...
# 13181         0       0      0            0      0            ...
# 15309         0       0      1            0      0            ...
# 16798         0       0      0            0      0            ...
#
#        émilegaudreault  éricrohmer  étiennechatiliez  étiennefaure  \
# 0                    0           0                 0             0
# 11055                0           0                 0             0
# 13181                0           0                 0             0
# 15309                0           0                 0             0
# 16798                0           0                 0             0
#
#        óskarjónasson  óskarthóraxelsson  ömerfaruksorak  ömervargi  \
# 0                  0                  0               0          0
# 11055              0                  0               0          0
# 13181              0                  0               0          0
# 15309              0                  0               0          0
# 16798              0                  0               0          0
#
#        özerkiziltan  özhaneren,muratsaraçoglu
# 0                 0                         0
# 11055             0                         0
# 13181             0                         0
# 15309             0                         0
# 16798             0                         0
#
# [5 rows x 23433 columns]

# %%
# get dummies for director

# %%
directors = movie_dummies['Director'].str.get_dummies()

# %%
directors.head()
# Out:
#        50cent  a.b.stone  a.j.edwards  a.m.lukas  a.r.murugadoss  \
# 0           0          0            0          0               0
# 11055       0          0            0          0               0
# 13181       0          0            0          0               0
# 15309       0          0            0          0               0
# 16798       0          0            0          0               0
#
#        aamirkhan,amolegupte  aanandl.rai  aaronaites,audreyewell  \
# 0                         0            0                       0
# 11055                     0            0                       0
# 13181                     0            0                       0
# 15309                     0            0                       0
# 16798                     0            0                       0
#
#        aaronblaise,robertwalker  aaroncassara            ...             \
# 0                             0             0            ...
# 11055                         0             0            ...
# 13181                         0             0            ...
# 15309                         0             0            ...
# 16798                         0             0            ...
#
#        émilegaudreault  éricrohmer  étiennechatiliez  étiennefaure  \
# 0                    0           0                 0             0
# 11055                0           0                 0             0
# 13181                0           0                 0             0
# 15309                0           0                 0             0
# 16798                0           0                 0             0
#
#        óskarjónasson  óskarthóraxelsson  ömerfaruksorak  ömervargi  \
# 0                  0                  0               0          0
# 11055              0                  0               0          0
# 13181              0                  0               0          0
# 15309              0                  0               0          0
# 16798              0                  0               0          0
#
#        özerkiziltan  özhaneren,muratsaraçoglu
# 0                 0                         0
# 11055             0                         0
# 13181             0                         0
# 15309             0                         0
# 16798             0                         0
#
# [5 rows x 5121 columns]

# %%
# join directors to movie_dummies

movie_dummies = pd.merge(movie_dummies, directors, how = 'inner', left_index = True, right_index = True)

# %%
movie_dummies.head()
# Out:
#                Title          Director  Action  Adventure  Animation  \
# 0          Toy Story      johnlasseter       0          1          1
# 11055        Sabrina       billywilder       0          0          0
# 13181  Mortal Kombat  paulw.s.anderson       1          1          0
# 15309        Hackers       iainsoftley       1          1          0
# 16798     Waterworld     kevinreynolds       1          1          0
#
#        Children  Comedy  Crime  Documentary  Drama  \
# 0             1       1      0            0      0
# 11055         0       1      0            0      0
# 13181         0       0      0            0      0
# 15309         0       0      1            0      0
# 16798         0       0      0            0      0
#
#                   ...              émilegaudreault_y  éricrohmer_y  \
# 0                 ...                              0             0
# 11055             ...                              0             0
# 13181             ...                              0             0
# 15309             ...                              0             0
# 16798             ...                              0             0
#
#        étiennechatiliez_y  étiennefaure_y  óskarjónasson_y  \
# 0                       0               0                0
# 11055                   0               0                0
# 13181                   0               0                0
# 15309                   0               0                0
# 16798                   0               0                0
#
#        óskarthóraxelsson_y  ömerfaruksorak_y  ömervargi_y  özerkiziltan_y  \
# 0                        0                 0            0               0
# 11055                    0                 0            0               0
# 13181                    0                 0            0               0
# 15309                    0                 0            0               0
# 16798                    0                 0            0               0
#
#        özhaneren,muratsaraçoglu_y
# 0                               0
# 11055                           0
# 13181                           0
# 15309                           0
# 16798                           0
#
# [5 rows x 28554 columns]

# %%
movie_dummies.drop(['Director'], axis=1, inplace =True)

# %%
movie_dummies.head()
# Out:
#                Title  Action  Adventure  Animation  Children  Comedy  Crime  \
# 0          Toy Story       0          1          1         1       1      0
# 11055        Sabrina       0          0          0         0       1      0
# 13181  Mortal Kombat       1          1          0         0       0      0
# 15309        Hackers       1          1          0         0       0      1
# 16798     Waterworld       1          1          0         0       0      0
#
#        Documentary  Drama  Fantasy             ...              \
# 0                0      0        1             ...
# 11055            0      0        0             ...
# 13181            0      0        1             ...
# 15309            0      0        0             ...
# 16798            0      0        0             ...
#
#        émilegaudreault_y  éricrohmer_y  étiennechatiliez_y  étiennefaure_y  \
# 0                      0             0                   0               0
# 11055                  0             0                   0               0
# 13181                  0             0                   0               0
# 15309                  0             0                   0               0
# 16798                  0             0                   0               0
#
#        óskarjónasson_y  óskarthóraxelsson_y  ömerfaruksorak_y  ömervargi_y  \
# 0                    0                    0                 0            0
# 11055                0                    0                 0            0
# 13181                0                    0                 0            0
# 15309                0                    0                 0            0
# 16798                0                    0                 0            0
#
#        özerkiziltan_y  özhaneren,muratsaraçoglu_y
# 0                   0                           0
# 11055               0                           0
# 13181               0                           0
# 15309               0                           0
# 16798               0                           0
#
# [5 rows x 28553 columns]

# %%
movie_dummies.to_csv('data/movies_w_dummies.csv', index = True)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
test_movie = movie_dummies.iloc[1]

test_movie
# Out:
# Title                         Sabrina
# Action                              0
# Adventure                           0
# Animation                           0
# Children                            0
# Comedy                              1
# Crime                               0
# Documentary                         0
# Drama                               0
# Fantasy                             0
# Film-Noir                           0
# Horror                              0
# IMAX                                0
# Musical                             0
# Mystery                             0
# Romance                             1
# Sci-Fi                              0
# Thriller                            0
# War                                 0
# Western                             0
# 'snub'pollard                       0
# 50cent_x                            0
# 7yearbitch                          0
# a.j.cook                            0
# a.j.langer                          0
# a.michaelbaldwin                    0
# aaliyah                             0
# aamirkhan                           0
# aaranthomas                         0
# aarneaksila                         0
#                                ...
# zanevella_y                         0
# zazaurushadze_y                     0
# zdravkosotra_y                      0
# zekidemirkubuz_y                    0
# zhengxu                             0
# zhorakryzhovnikov_y                 0
# zhuangzhuangtian_y                  0
# ziaddoueiri_y                       0
# ziskariemann_y                      0
# zoeclarke-williams_y                0
# zoer.cassavetes_y                   0
# zoyaakhtar_y                        0
# ádámcsászi_y                        0
# álexdelaiglesia_y                   0
# álvarobrechner_y                    0
# álvarolongoria                      0
# ángelmuñiz_y                        0
# åkelindman_y                        0
# çaganirmak_y                        0
# éliechouraqui_y                     0
# émilegaudreault_y                   0
# éricrohmer_y                        0
# étiennechatiliez_y                  0
# étiennefaure_y                      0
# óskarjónasson_y                     0
# óskarthóraxelsson_y                 0
# ömerfaruksorak_y                    0
# ömervargi_y                         0
# özerkiziltan_y                      0
# özhaneren,muratsaraçoglu_y          0
# Name: 11055, Length: 28553, dtype: object

# %% [markdown]
# Content System based on Bag of Words Method

# %%
# remove spaces from actors and director names

def clean_data(x):
    if isinstance(x, list):
        return[str.lower(i.replace(" ", "")) for i in x]
    else:
        if isinstance(x, str):
            return str.lower(x.replace(" ", ""))
        else:
            return ''

# %%
movies_alt = movies_only.copy()

movies_alt.shape
# Out:
# (9264, 4)

# %%
credits = ['Actors', 'Director']

for credit in credits:
    movies_alt[credit] = movies_alt[credit].apply(clean_data)

# %%
movies_alt.head()
# Out:
#                Title                                       genres  \
# 0          Toy Story  Adventure|Animation|Children|Comedy|Fantasy
# 11055        Sabrina                               Comedy|Romance
# 13181  Mortal Kombat                     Action|Adventure|Fantasy
# 15309        Hackers              Action|Adventure|Crime|Thriller
# 16798     Waterworld                      Action|Adventure|Sci-Fi
#
#                Director                                             Actors
# 0          johnlasseter             tomhanks,timallen,donrickles,jimvarney
# 11055       billywilder  humphreybogart,audreyhepburn,williamholden,wal...
# 13181  paulw.s.anderson  christopherlambert,robinshou,lindenashby,cary-...
# 15309       iainsoftley  jonnyleemiller,angelinajolie,jessebradford,mat...
# 16798     kevinreynolds      kevincostner,chaimjeraffi,rickaviles,r.d.call

# %%
# remove | from genres

movies_alt['genres'] = movies_alt['genres'].str.replace("|", " ")

# %%
movies_alt.head()
# Out:
#                Title                                       genres  \
# 0          Toy Story  Adventure Animation Children Comedy Fantasy
# 11055        Sabrina                               Comedy Romance
# 13181  Mortal Kombat                     Action Adventure Fantasy
# 15309        Hackers              Action Adventure Crime Thriller
# 16798     Waterworld                      Action Adventure Sci-Fi
#
#                Director                                             Actors
# 0          johnlasseter             tomhanks,timallen,donrickles,jimvarney
# 11055       billywilder  humphreybogart,audreyhepburn,williamholden,wal...
# 13181  paulw.s.anderson  christopherlambert,robinshou,lindenashby,cary-...
# 15309       iainsoftley  jonnyleemiller,angelinajolie,jessebradford,mat...
# 16798     kevinreynolds      kevincostner,chaimjeraffi,rickaviles,r.d.call

# %%
#combine all data 

def create_soup(x):
    return  x['Actors'].replace(',',' ') + ' ' + x['Director'] + ' ' + ' '.join(x['genres'])

# %%
movies_alt['bag_of_words'] = movies_alt.apply(create_soup, axis=1)

# %%
movies_alt.set_index('Title')
# Out:
#                                                                                          genres  \
# Title
# Toy Story                                           Adventure Animation Children Comedy Fantasy
# Sabrina                                                                          Comedy Romance
# Mortal Kombat                                                          Action Adventure Fantasy
# Hackers                                                         Action Adventure Crime Thriller
# Waterworld                                                              Action Adventure Sci-Fi
# Beverly Hills Cop III                                              Action Comedy Crime Thriller
# Tombstone                                                                  Action Drama Western
# Courage Under Fire                                                       Action Crime Drama War
# Ransom                                                                           Crime Thriller
# Tin Cup                                                                    Comedy Drama Romance
# Groundhog Day                                                            Comedy Fantasy Romance
# Unforgiven                                                                        Drama Western
# Dracula                                                         Fantasy Horror Romance Thriller
# Cape Fear                                                                              Thriller
# Night Falls on Manhattan                                                            Crime Drama
# Beavis and Butt-Head Do America                                Adventure Animation Comedy Crime
# Anaconda                                                              Action Adventure Thriller
# Spawn                                                          Action Adventure Sci-Fi Thriller
# Fire Down Below                                                           Action Drama Thriller
# Gattaca                                                                   Drama Sci-Fi Thriller
# U.S. Marshals                                                             Action Crime Thriller
# Deep Impact                                                               Drama Sci-Fi Thriller
# Godzilla                                                                 Action Sci-Fi Thriller
# SLC Punk!                                                                          Comedy Drama
# eXistenZ                                                                 Action Sci-Fi Thriller
# Backdraft                                                                          Action Drama
# Deuce Bigalow: Male Gigolo                                                               Comedy
# Galaxy Quest                                                            Adventure Comedy Sci-Fi
# Mission to Mars                                                                          Sci-Fi
# Scary Movie                                                                       Comedy Horror
# ...                                                                                         ...
# Ride                                                                                      Drama
# Extreme Movie                                                                            Comedy
# Nayak: The Real Hero                                                               Action Drama
# Hate Story 2                                                             Drama Romance Thriller
# Far                                                                                       Drama
# Blackwoods                                                                       Drama Thriller
# Gunless                                                             Action Comedy Drama Western
# Route Irish                                                                      Drama Thriller
# Reykjavik-Rotterdam                                                              Drama Thriller
# Hammer of the Gods                                                                       Action
# Child of God                                                               Crime Drama Thriller
# Last Will                                                                        Drama Thriller
# Kill Your Friends                                                         Comedy Crime Thriller
# Now You See It...                                                                Comedy Mystery
# Eating Out 2: Sloppy Seconds                                                     Comedy Romance
# Spin                                                                       Comedy Drama Romance
# Someone Else's America                                                                    Drama
# The Land Before Time IV: Journey Through the Mists                 Adventure Animation Children
# The Land Before Time V: The Mysterious Island                      Adventure Animation Children
# The Land Before Time VI: The Secret of Saurus Rock                           Animation Children
# Scooby-Doo! Abracadabra-Doo                                          Animation Children Mystery
# Scooby-Doo and the Alien Invaders                                            Animation Children
# 2012: Time for Change                                                     Animation Documentary
# Video Games: The Movie                                                              Documentary
# Big Star: Nothing Can Hurt Me                                                       Documentary
# Breadcrumb Trail                                                                    Documentary
# Such Good People                                                                 Comedy Mystery
# Toothless                                                                       Children Comedy
# Rebels of the Neon God                                                                    Drama
# Expired                                                                    Comedy Drama Romance
#
#                                                                                            Director  \
# Title
# Toy Story                                                                              johnlasseter
# Sabrina                                                                                 billywilder
# Mortal Kombat                                                                      paulw.s.anderson
# Hackers                                                                                 iainsoftley
# Waterworld                                                                            kevinreynolds
# Beverly Hills Cop III                                                                    johnlandis
# Tombstone                                                               georgep.cosmatos,kevinjarre
# Courage Under Fire                                                                      edwardzwick
# Ransom                                                                                    ronhoward
# Tin Cup                                                                                  ronshelton
# Groundhog Day                                                                           haroldramis
# Unforgiven                                                                            clinteastwood
# Dracula                                                                      todbrowning,karlfreund
# Cape Fear                                                                            martinscorsese
# Night Falls on Manhattan                                                                sidneylumet
# Beavis and Butt-Head Do America                     mikejudge,mikedeseve,brianmulroney,yvettekaplan
# Anaconda                                                                                  luisllosa
# Spawn                                                                                 marka.z.dippé
# Fire Down Below                                                                 félixenríquezalcalá
# Gattaca                                                                                andrewniccol
# U.S. Marshals                                                                           stuartbaird
# Deep Impact                                                                               mimileder
# Godzilla                                                                              garethedwards
# SLC Punk!                                                                            jamesmerendino
# eXistenZ                                                                            davidcronenberg
# Backdraft                                                                                 ronhoward
# Deuce Bigalow: Male Gigolo                                                             mikemitchell
# Galaxy Quest                                                                            deanparisot
# Mission to Mars                                                                        briandepalma
# Scary Movie                                                                       keenenivorywayans
# ...                                                                                             ...
# Ride                                                                                      helenhunt
# Extreme Movie                                                         adamjayepstein,andrewjacobson
# Nayak: The Real Hero                                                                      s.shankar
# Hate Story 2                                                                           vishalpandya
# Far                                                                                    andrétéchiné
# Blackwoods                                                                                  uweboll
# Gunless                                                                             williamphillips
# Route Irish                                                                                kenloach
# Reykjavik-Rotterdam                                                                   óskarjónasson
# Hammer of the Gods                                                                  farrenblackburn
# Child of God                                                                            jamesfranco
# Last Will                                                                                 brenthuff
# Kill Your Friends                                                                        owenharris
# Now You See It...                                                                     duwaynedunham
# Eating Out 2: Sloppy Seconds                                                       phillipj.bartell
# Spin                                                                                    jaminwinans
# Someone Else's America                                                             goranpaskaljevic
# The Land Before Time IV: Journey Through the Mists                                    royallensmith
# The Land Before Time V: The Mysterious Island                                      charlesgrosvenor
# The Land Before Time VI: The Secret of Saurus Rock                                 charlesgrosvenor
# Scooby-Doo! Abracadabra-Doo                                                 spikebrandt,tonycervone
# Scooby-Doo and the Alien Invaders                                                      jimstenstrum
# 2012: Time for Change                                                                  joaog.amorim
# Video Games: The Movie                                                                  jeremysnead
# Big Star: Nothing Can Hurt Me                                  drewdenicola,oliviamori(co-director)
# Breadcrumb Trail                                                                         lancebangs
# Such Good People                                                                        stewartwade
# Toothless                                                                             melaniemayron
# Rebels of the Neon God                                                               ming-liangtsai
# Expired                                                                            ceciliaminiucchi
#
#                                                                                                Actors  \
# Title
# Toy Story                                                      tomhanks,timallen,donrickles,jimvarney
# Sabrina                                             humphreybogart,audreyhepburn,williamholden,wal...
# Mortal Kombat                                       christopherlambert,robinshou,lindenashby,cary-...
# Hackers                                             jonnyleemiller,angelinajolie,jessebradford,mat...
# Waterworld                                              kevincostner,chaimjeraffi,rickaviles,r.d.call
# Beverly Hills Cop III                                eddiemurphy,jontenney,joeytravolta,eugenecollier
# Tombstone                                                 kurtrussell,valkilmer,samelliott,billpaxton
# Courage Under Fire                                  denzelwashington,megryan,loudiamondphillips,mi...
# Ransom                                                    melgibson,renerusso,brawleynolte,garysinise
# Tin Cup                                                 kevincostner,renerusso,donjohnson,cheechmarin
# Groundhog Day                                       billmurray,andiemacdowell,chriselliott,stephen...
# Unforgiven                                          clinteastwood,genehackman,morganfreeman,richar...
# Dracula                                              belalugosi,helenchandler,davidmanners,dwightfrye
# Cape Fear                                           robertdeniro,nicknolte,jessicalange,juliettelewis
# Night Falls on Manhattan                                  andygarcia,ianholm,jamesgandolfini,lenaolin
# Beavis and Butt-Head Do America                        mikejudge,brucewillis,demimoore,clorisleachman
# Anaconda                                                   jenniferlopez,icecube,jonvoight,ericstoltz
# Spawn                                               michaeljaiwhite,johnleguizamo,martinsheen,ther...
# Fire Down Below                                     stevenseagal,marghelgenberger,stephenlang,brad...
# Gattaca                                                ethanhawke,umathurman,gorevidal,xanderberkeley
# U.S. Marshals                                       tommyleejones,wesleysnipes,robertdowneyjr.,joe...
# Deep Impact                                          robertduvall,téaleoni,elijahwood,vanessaredgrave
# Godzilla                                            aarontaylor-johnson,cjadams,kenwatanabe,bryanc...
# SLC Punk!                                           matthewlillard,michaela.goorjian,annabethgish,...
# eXistenZ                                               jenniferjasonleigh,judelaw,ianholm,willemdafoe
# Backdraft                                           kurtrussell,williambaldwin,robertdeniro,donald...
# Deuce Bigalow: Male Gigolo                          robschneider,williamforsythe,eddiegriffin,arij...
# Galaxy Quest                                        timallen,sigourneyweaver,alanrickman,tonyshalhoub
# Mission to Mars                                        garysinise,timrobbins,doncheadle,connienielsen
# Scary Movie                                         carmenelectra,davesheridan,frankb.moore,giacom...
# ...                                                                                               ...
# Ride                                                helenhunt,brentonthwaites,juliedretzin,jayrussell
# Extreme Movie                                       patrickj.adams,deniseboutte,brianburt,michaelcera
# Nayak: The Real Hero                                    anilkapoor,ranimukerji,amrishpuri,johnnylever
# Hate Story 2                                        jaybhanushali,surveenchawla,sushantsingh,siddh...
# Far                                                 stéphanerideau,lubnaazabal,mohamedhamaidi,yasm...
# Blackwoods                                          patrickmuldoon,keeganconnortracy,willsanderson...
# Gunless                                             paulgross,siennaguillory,dustinmilligan,tylermane
# Route Irish                                                markwomack,andrealowe,johnbishop,geoffbell
# Reykjavik-Rotterdam                                 baltasarkormákur,ingvareggertsigurðsson,liljan...
# Hammer of the Gods                                  charliebewley,clivestanden,jamescosmo,elliotcowan
# Child of God                                          scotthaze,timblakenelson,jimparrack,stevehunter
# Last Will                                           tatumo'neal,tomberenger,patrickmuldoon,peterco...
# Kill Your Friends                                   nicholashoult,jamescorden,georgiaking,craigrob...
# Now You See It...                                   alymichalka,johnnypacar,franklangella,chrisoli...
# Eating Out 2: Sloppy Seconds                        jimverraros,emilybrookehands,rebekahkochan,bre...
# Spin                                                raymondandrewbailey,cesarbejarano,brandoncarri...
# Someone Else's America                              tomconti,predrag'miki'manojlovic,maríacasares,...
# The Land Before Time IV: Journey Through the Mists    johningle,candacehutson,heatherhogan,robpaulsen
# The Land Before Time V: The Mysterious Island       johningle,brandonlacroix,arianoellecurzon,robp...
# The Land Before Time VI: The Secret of Saurus Rock  thomasdekker,kennethmars,anndimcafee,arianoell...
# Scooby-Doo! Abracadabra-Doo                          frankwelker,matthewlillard,greygriffin,mindycohn
# Scooby-Doo and the Alien Invaders                      scottinnes,marykaybergman,frankwelker,b.j.ward
# 2012: Time for Change                               danielpinchbeck,maudebarlow,arianeburgess,gera...
# Video Games: The Movie                              seanastin,alalcorn,peterarmstrong,cliffbleszinski
# Big Star: Nothing Can Hurt Me                               billyaltman,jonauer,lesterbangs,chrisbell
# Breadcrumb Trail                                     stevealbini,toddbrashear,ianmackaye,brianmcmahan
# Such Good People                                    michaelurie,randyharrison,jamesurbaniak,scottwolf
# Toothless                                           kirstiealley,dalemidkiff,rossmalinger,darylmit...
# Rebels of the Neon God                              chao-jungchen,chang-binjen,kang-shenglee,yi-ch...
# Expired                                             samanthamorton,anthonyjohncrane,ginast.john,ro...
#
#                                                                                          bag_of_words
# Title
# Toy Story                                           tomhanks timallen donrickles jimvarney johnlas...
# Sabrina                                             humphreybogart audreyhepburn williamholden wal...
# Mortal Kombat                                       christopherlambert robinshou lindenashby cary-...
# Hackers                                             jonnyleemiller angelinajolie jessebradford mat...
# Waterworld                                          kevincostner chaimjeraffi rickaviles r.d.call ...
# Beverly Hills Cop III                               eddiemurphy jontenney joeytravolta eugenecolli...
# Tombstone                                           kurtrussell valkilmer samelliott billpaxton ge...
# Courage Under Fire                                  denzelwashington megryan loudiamondphillips mi...
# Ransom                                              melgibson renerusso brawleynolte garysinise ro...
# Tin Cup                                             kevincostner renerusso donjohnson cheechmarin ...
# Groundhog Day                                       billmurray andiemacdowell chriselliott stephen...
# Unforgiven                                          clinteastwood genehackman morganfreeman richar...
# Dracula                                             belalugosi helenchandler davidmanners dwightfr...
# Cape Fear                                           robertdeniro nicknolte jessicalange juliettele...
# Night Falls on Manhattan                            andygarcia ianholm jamesgandolfini lenaolin si...
# Beavis and Butt-Head Do America                     mikejudge brucewillis demimoore clorisleachman...
# Anaconda                                            jenniferlopez icecube jonvoight ericstoltz lui...
# Spawn                                               michaeljaiwhite johnleguizamo martinsheen ther...
# Fire Down Below                                     stevenseagal marghelgenberger stephenlang brad...
# Gattaca                                             ethanhawke umathurman gorevidal xanderberkeley...
# U.S. Marshals                                       tommyleejones wesleysnipes robertdowneyjr. joe...
# Deep Impact                                         robertduvall téaleoni elijahwood vanessaredgra...
# Godzilla                                            aarontaylor-johnson cjadams kenwatanabe bryanc...
# SLC Punk!                                           matthewlillard michaela.goorjian annabethgish ...
# eXistenZ                                            jenniferjasonleigh judelaw ianholm willemdafoe...
# Backdraft                                           kurtrussell williambaldwin robertdeniro donald...
# Deuce Bigalow: Male Gigolo                          robschneider williamforsythe eddiegriffin arij...
# Galaxy Quest                                        timallen sigourneyweaver alanrickman tonyshalh...
# Mission to Mars                                     garysinise timrobbins doncheadle connienielsen...
# Scary Movie                                         carmenelectra davesheridan frankb.moore giacom...
# ...                                                                                               ...
# Ride                                                helenhunt brentonthwaites juliedretzin jayruss...
# Extreme Movie                                       patrickj.adams deniseboutte brianburt michaelc...
# Nayak: The Real Hero                                anilkapoor ranimukerji amrishpuri johnnylever ...
# Hate Story 2                                        jaybhanushali surveenchawla sushantsingh siddh...
# Far                                                 stéphanerideau lubnaazabal mohamedhamaidi yasm...
# Blackwoods                                          patrickmuldoon keeganconnortracy willsanderson...
# Gunless                                             paulgross siennaguillory dustinmilligan tylerm...
# Route Irish                                         markwomack andrealowe johnbishop geoffbell ken...
# Reykjavik-Rotterdam                                 baltasarkormákur ingvareggertsigurðsson liljan...
# Hammer of the Gods                                  charliebewley clivestanden jamescosmo elliotco...
# Child of God                                        scotthaze timblakenelson jimparrack stevehunte...
# Last Will                                           tatumo'neal tomberenger patrickmuldoon peterco...
# Kill Your Friends                                   nicholashoult jamescorden georgiaking craigrob...
# Now You See It...                                   alymichalka johnnypacar franklangella chrisoli...
# Eating Out 2: Sloppy Seconds                        jimverraros emilybrookehands rebekahkochan bre...
# Spin                                                raymondandrewbailey cesarbejarano brandoncarri...
# Someone Else's America                              tomconti predrag'miki'manojlovic maríacasares ...
# The Land Before Time IV: Journey Through the Mists  johningle candacehutson heatherhogan robpaulse...
# The Land Before Time V: The Mysterious Island       johningle brandonlacroix arianoellecurzon robp...
# The Land Before Time VI: The Secret of Saurus Rock  thomasdekker kennethmars anndimcafee arianoell...
# Scooby-Doo! Abracadabra-Doo                         frankwelker matthewlillard greygriffin mindyco...
# Scooby-Doo and the Alien Invaders                   scottinnes marykaybergman frankwelker b.j.ward...
# 2012: Time for Change                               danielpinchbeck maudebarlow arianeburgess gera...
# Video Games: The Movie                              seanastin alalcorn peterarmstrong cliffbleszin...
# Big Star: Nothing Can Hurt Me                       billyaltman jonauer lesterbangs chrisbell drew...
# Breadcrumb Trail                                    stevealbini toddbrashear ianmackaye brianmcmah...
# Such Good People                                    michaelurie randyharrison jamesurbaniak scottw...
# Toothless                                           kirstiealley dalemidkiff rossmalinger darylmit...
# Rebels of the Neon God                              chao-jungchen chang-binjen kang-shenglee yi-ch...
# Expired                                             samanthamorton anthonyjohncrane ginast.john ro...
#
# [9264 rows x 4 columns]

# %%
movies_bow = movies_alt[['Title', 'bag_of_words']]

movies_bow.set_index('Title', inplace=True)

# %%
# Import sklearn models

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# instantiating and generating the count matrix
count = CountVectorizer()
count_matrix = count.fit_transform(movies_bow['bag_of_words'])


# generating the cosine similarity matrix
cosine_sim = cosine_similarity(count_matrix, count_matrix)

# %%
indices = pd.Series(movies_bow.index, index = movies_bow['Title'])

def get_recommendations(title, cosine_sim=cosine_sim):
    # Get the index of the movie that matches the title
    idx = indices[title]

    # Get the pairwsie similarity scores of all movies with that movie
    sim_scores = list(enumerate(cosine_sim[idx]))

    # Sort the movies based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the scores of the 10 most similar movies
    sim_scores = sim_scores[1:11]

    # Get the movie indices
    movie_indices = [i[0] for i in sim_scores]

    # Return the top 10 most similar movies
    return movies_bow['Title'].iloc[movie_indices]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Title'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-116-c1b3ecb14bea> in <module>()
# ----> 1 indices = pd.Series(movies_bow.index, index = movies_bow['Title'])
#       2
#       3 def get_recommendations(title, cosine_sim=cosine_sim):
#       4     # Get the index of the movie that matches the title
#       5     idx = indices[title]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Title'

# %%
# # Convert movie titles to numerical so they are associated to an ordered numerical. store in a series
# # This will be used in the function to match the indexes of the movies

# indices = pd.Series(movies_df.index)

# #  defining the function that takes in movie title 
# # as input and returns the top 10 recommended movies
# def recommendations(title, cosine_sim = cosine_sim):
    
#     # initializing the empty list of recommended movies
#     recommended_movies = []
    
#     # gettin the index of the movie that matches the title
#     idx = indices[indices == title].index[0]

#     # creating a Series with the similarity scores in descending order
#     score_series = pd.Series(cosine_sim[idx]).sort_values(ascending = False)

#     # getting the indexes of the 10 most similar movies
#     top_10_indexes = list(score_series.iloc[1:11].index)
    
#     # populating the list with the titles of the best 10 matching movies
#     for i in top_10_indexes:
#         recommended_movies.append(list(movies_df.index)[i])
        
#     return recommended_movies

# %%
get_recommendations('Toy Story')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-117-ecc914e2fdb6> in <module>()
# ----> 1 get_recommendations('Toy Story')
#
# <ipython-input-114-48158acbe099> in get_recommendations(title, cosine_sim)
#       6
#       7     # Get the pairwsie similarity scores of all movies with that movie
# ----> 8     sim_scores = list(enumerate(cosine_sim[idx]))
#       9
#      10     # Sort the movies based on the similarity scores
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
indices
# Out:
# Title
# Rumble in the Bronx                       0
# Batman Forever                          831
# Desperado                              3098
# Die Hard: With a Vengeance             4099
# First Knight                           8967
# Mallrats                              10088
# Clerks                                10493
# Hot Shots! Part Deux                  12244
# Dead Man                              13290
# Die Hard 2                            13465
# Batman Returns                        14097
# Donnie Brasco                         14502
# Liar Liar                             14937
# Grosse Pointe Blank                   15716
# Face/Off                              16300
# City of Angels                        17175
# Cube                                  17371
# Happiness                             17613
# American History X                    17957
# Enemy of the State                    19928
# Office Space                          20625
# Wing Commander                        21996
# Ravenous                              22043
# American Pie                          22095
# Boiler Room                           23468
# Ghost Dog: The Way of the Samurai     23694
# Requiem for a Dream                   23970
# Charlie's Angels                      25204
# Dungeons & Dragons                    26047
# Valentine                             26254
#                                       ...
# Dadetown                             774560
# Wheel of Time                        774561
# Romanzo Criminale                    774562
# Far                                  774563
# Heart of America                     774564
# Special                              774565
# Blackwoods                           774566
# Gunless                              774567
# Route Irish                          774568
# Reykjavik-Rotterdam                  774569
# Hammer of the Gods                   774570
# Child of God                         774571
# Last Will                            774572
# Kill Your Friends                    774573
# Now You See It...                    774574
# War on Everyone                      774575
# Eating Out 2: Sloppy Seconds         774576
# Spin                                 774577
# Craigslist Joe                       774581
# Living on One Dollar                 774582
# Video Games: The Movie               774583
# Big Star: Nothing Can Hurt Me        774584
# Rams                                 774585
# Maggie's Plan                        774586
# Breadcrumb Trail                     774587
# Last Train Home                      774588
# The Wolfpack                         774589
# Such Good People                     774590
# 4 Moons                              774591
# Seashore                             774592
# Length: 7003, dtype: int64
